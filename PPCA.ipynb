# %%
import numpy as np
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import scipy.io as io
from scipy.io import loadmat
from scipy.io import savemat
import torch.utils.data as data_utils
import torch.optim as optim
import matplotlib.pyplot as plt
import math

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Assuming that we are on a CUDA machine, this should print a CUDA device:
print(device)
# Out:
# C:\Anaconda3\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: '[WinError 127] The specified procedure could not be found'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# cuda:0

# %%
from torchvision.transforms import Compose, Resize, CenterCrop, ToTensor, Normalize
from PIL import Image

try:
    from torchvision.transforms import InterpolationMode
    BICUBIC = InterpolationMode.BICUBIC
except ImportError:
    BICUBIC = Image.BICUBIC

def load_data(path,file):
    name=path+file
    m=loadmat(name)
    x=torch.tensor(m['feature']).to(device)
    return x.float()

def _convert_image_to_rgb(image):
    return image.convert("RGB")

# %%
import clip

def _transform(n_px):
    return Compose([
        Resize(n_px, interpolation=BICUBIC),
        CenterCrop(n_px),
        _convert_image_to_rgb,
        ToTensor(),
        Normalize((0.48145466, 0.4578275, 0.40821073), (0.26862954, 0.26130258, 0.27577711)),
    ])

def features(net, x):
    x = x.type(net.conv1.weight.dtype)
    for conv, bn in [(net.conv1, net.bn1), (net.conv2, net.bn2), (net.conv3, net.bn3)]:
        x = F.relu(bn(conv(x)))
    x = net.avgpool(x)
    x = net.layer1(x)
    x = net.layer2(x)
    x = net.layer3(x)
    x = net.layer4(x)
    x = net.attnpool(x)
    return x

print(clip.available_models())
model, preprocess = clip.load('RN50x4', device)
# Out:
# ['RN50', 'RN101', 'RN50x4', 'RN50x16', 'RN50x64', 'ViT-B/32', 'ViT-B/16', 'ViT-L/14', 'ViT-L/14@336px']

# %%
#Billion-scale semi-supervised learning for image classification, https://arxiv.org/abs/1905.00546
def features(net, x):
    # See note [TorchScript super()]
    x = net.conv1(x)
    x = net.bn1(x)
    x = net.relu(x)
    x = net.maxpool(x)

    x = net.layer1(x)
    x = net.layer2(x)
    x = net.layer3(x)
    x = net.layer4(x)
    
    #print(x.shape)
    x = F.avg_pool2d(x,x.shape[2],1)
    x = torch.flatten(x, 1)
    return x

def _transform(n_px):
    return Compose([
        Resize(n_px, interpolation=BICUBIC),
        CenterCrop(n_px),
        _convert_image_to_rgb,
        ToTensor(),
        Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
    ])

torch.hub.list('facebookresearch/semi-supervised-ImageNet1K-models')
model = torch.hub.load('facebookresearch/semi-supervised-ImageNet1K-models', 'resnet50_swsl')
model=model.to(device)
model.eval()
# Out:
# Using cache found in C:\Users\abarbu/.cache\torch\hub\facebookresearch_semi-supervised-ImageNet1K-models_master
# Using cache found in C:\Users\abarbu/.cache\torch\hub\facebookresearch_semi-supervised-ImageNet1K-models_master
# C:\Anaconda3\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Anaconda3\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
from torchvision.datasets import CIFAR100
from torch.utils.data import DataLoader
    
data = CIFAR100(root='c:/datasets/CIFAR100', download=True, train=True,transform=_transform(32))
#data = CIFAR100(root='c:/datasets/CIFAR100', download=True, train=True,transform=preprocess)
loader = DataLoader(data, batch_size=250, shuffle=False, num_workers=0)
# Out:
# Files already downloaded and verified

# %%
data = CIFAR100(root='c:/datasets/CIFAR100', download=True, train=False,transform=_transform(256))
loader = DataLoader(data, batch_size=250, shuffle=False, num_workers=0)
# Out:
# Files already downloaded and verified

# %%
# compute features using loader
i=0
for d in loader:
    images,yi=d
    images=images.to(device)
    with torch.no_grad():
        #print(images.shape)
        fi=features32(model.visual,images)    
    if i==0:
        X=fi.cpu()
        y=yi
    else:
        X=torch.cat((X,fi.cpu()),dim=0)
        y=torch.cat((y,yi),dim=0)
    i+=1
    if i%10==0:
        print(i,X.shape)
        
X=X.squeeze()
print(X.shape)

# %%
name = 'train.txt'
#name = 'c:/datasets/Imagenet/train.txt'
with open(name, 'r') as f:
    names = f.read().splitlines()
nc=len(names)
print(nc)
classes=torch.load('classes_val.pth')
# Out:
# 1000

# %%
# compute features for Imagenet and save them
from os import listdir
from os.path import isfile, join
from PIL import Image
from torch.utils.data import Dataset,TensorDataset, DataLoader

def ComputeFeatures(path,files,nx): 
    n=len(files)
    x=torch.zeros([n,3,nx,nx], dtype=torch.float32)
    for i in range(n):
        im = Image.open(join(path, files[i]))
        x[i,:,:,:]=_transform(nx)(im)
    data=TensorDataset(x)
    loader=DataLoader(data,batch_size=256,shuffle=False)
    i=0
    for images in loader:
        images=images[0].to(device)
        with torch.no_grad():
            fi=features32(model.visual,images)    
        if i==0:
            X=fi.cpu()
        else:
            X=torch.cat((X,fi.cpu()),dim=0)
        i+=1
    return X.squeeze()

nx=288
for i in range(nc):
    path='C:/Datasets/ILSVRC2016/ILSVRC/Data/CLS-LOC/train/'+names[i]
    files = [f for f in listdir(path) if isfile(join(path, f))]
    x=ComputeFeatures(path,files,nx)
    name='C:/Datasets/ILSVRC2016/features_2560/'+names[i]+'.mat'
    print(i,name)
    savemat(name,{'feature':x.float().numpy()})
# Out:
# 0 C:/Datasets/ILSVRC2016/features_2560/n01440764.mat
# 1 C:/Datasets/ILSVRC2016/features_2560/n01443537.mat
# 2 C:/Datasets/ILSVRC2016/features_2560/n01484850.mat
# 3 C:/Datasets/ILSVRC2016/features_2560/n01491361.mat
# 4 C:/Datasets/ILSVRC2016/features_2560/n01494475.mat
# 5 C:/Datasets/ILSVRC2016/features_2560/n01496331.mat
# 6 C:/Datasets/ILSVRC2016/features_2560/n01498041.mat
# 7 C:/Datasets/ILSVRC2016/features_2560/n01514668.mat
# 8 C:/Datasets/ILSVRC2016/features_2560/n01514859.mat
# 9 C:/Datasets/ILSVRC2016/features_2560/n01518878.mat
# 10 C:/Datasets/ILSVRC2016/features_2560/n01530575.mat
# 11 C:/Datasets/ILSVRC2016/features_2560/n01531178.mat
# 12 C:/Datasets/ILSVRC2016/features_2560/n01532829.mat
# 13 C:/Datasets/ILSVRC2016/features_2560/n01534433.mat
# 14 C:/Datasets/ILSVRC2016/features_2560/n01537544.mat
# 15 C:/Datasets/ILSVRC2016/features_2560/n01558993.mat
# 16 C:/Datasets/ILSVRC2016/features_2560/n01560419.mat
# 17 C:/Datasets/ILSVRC2016/features_2560/n01580077.mat
# 18 C:/Datasets/ILSVRC2016/features_2560/n01582220.mat
# 19 C:/Datasets/ILSVRC2016/features_2560/n01592084.mat
# 20 C:/Datasets/ILSVRC2016/features_2560/n01601694.mat
# 21 C:/Datasets/ILSVRC2016/features_2560/n01608432.mat
# 22 C:/Datasets/ILSVRC2016/features_2560/n01614925.mat
# 23 C:/Datasets/ILSVRC2016/features_2560/n01616318.mat
# 24 C:/Datasets/ILSVRC2016/features_2560/n01622779.mat
# 25 C:/Datasets/ILSVRC2016/features_2560/n01629819.mat
# 26 C:/Datasets/ILSVRC2016/features_2560/n01630670.mat
# 27 C:/Datasets/ILSVRC2016/features_2560/n01631663.mat
# 28 C:/Datasets/ILSVRC2016/features_2560/n01632458.mat
# 29 C:/Datasets/ILSVRC2016/features_2560/n01632777.mat
# 30 C:/Datasets/ILSVRC2016/features_2560/n01641577.mat
# 31 C:/Datasets/ILSVRC2016/features_2560/n01644373.mat
# 32 C:/Datasets/ILSVRC2016/features_2560/n01644900.mat
# 33 C:/Datasets/ILSVRC2016/features_2560/n01664065.mat
# 34 C:/Datasets/ILSVRC2016/features_2560/n01665541.mat
# 35 C:/Datasets/ILSVRC2016/features_2560/n01667114.mat
# 36 C:/Datasets/ILSVRC2016/features_2560/n01667778.mat
# 37 C:/Datasets/ILSVRC2016/features_2560/n01669191.mat
# 38 C:/Datasets/ILSVRC2016/features_2560/n01675722.mat
# 39 C:/Datasets/ILSVRC2016/features_2560/n01677366.mat
# 40 C:/Datasets/ILSVRC2016/features_2560/n01682714.mat
# 41 C:/Datasets/ILSVRC2016/features_2560/n01685808.mat
# 42 C:/Datasets/ILSVRC2016/features_2560/n01687978.mat
# 43 C:/Datasets/ILSVRC2016/features_2560/n01688243.mat
# 44 C:/Datasets/ILSVRC2016/features_2560/n01689811.mat
# 45 C:/Datasets/ILSVRC2016/features_2560/n01692333.mat
# 46 C:/Datasets/ILSVRC2016/features_2560/n01693334.mat
# 47 C:/Datasets/ILSVRC2016/features_2560/n01694178.mat
# 48 C:/Datasets/ILSVRC2016/features_2560/n01695060.mat
# 49 C:/Datasets/ILSVRC2016/features_2560/n01697457.mat
# 50 C:/Datasets/ILSVRC2016/features_2560/n01698640.mat
# 51 C:/Datasets/ILSVRC2016/features_2560/n01704323.mat
# 52 C:/Datasets/ILSVRC2016/features_2560/n01728572.mat
# 53 C:/Datasets/ILSVRC2016/features_2560/n01728920.mat
# 54 C:/Datasets/ILSVRC2016/features_2560/n01729322.mat
# 55 C:/Datasets/ILSVRC2016/features_2560/n01729977.mat
# 56 C:/Datasets/ILSVRC2016/features_2560/n01734418.mat
# 57 C:/Datasets/ILSVRC2016/features_2560/n01735189.mat
# 58 C:/Datasets/ILSVRC2016/features_2560/n01737021.mat
# 59 C:/Datasets/ILSVRC2016/features_2560/n01739381.mat
# 60 C:/Datasets/ILSVRC2016/features_2560/n01740131.mat
# 61 C:/Datasets/ILSVRC2016/features_2560/n01742172.mat
# 62 C:/Datasets/ILSVRC2016/features_2560/n01744401.mat
# 63 C:/Datasets/ILSVRC2016/features_2560/n01748264.mat
# 64 C:/Datasets/ILSVRC2016/features_2560/n01749939.mat
# 65 C:/Datasets/ILSVRC2016/features_2560/n01751748.mat
# 66 C:/Datasets/ILSVRC2016/features_2560/n01753488.mat
# 67 C:/Datasets/ILSVRC2016/features_2560/n01755581.mat
# 68 C:/Datasets/ILSVRC2016/features_2560/n01756291.mat
# 69 C:/Datasets/ILSVRC2016/features_2560/n01768244.mat
# 70 C:/Datasets/ILSVRC2016/features_2560/n01770081.mat
# 71 C:/Datasets/ILSVRC2016/features_2560/n01770393.mat
# 72 C:/Datasets/ILSVRC2016/features_2560/n01773157.mat
# 73 C:/Datasets/ILSVRC2016/features_2560/n01773549.mat
# 74 C:/Datasets/ILSVRC2016/features_2560/n01773797.mat
# 75 C:/Datasets/ILSVRC2016/features_2560/n01774384.mat
# 76 C:/Datasets/ILSVRC2016/features_2560/n01774750.mat
# 77 C:/Datasets/ILSVRC2016/features_2560/n01775062.mat
# 78 C:/Datasets/ILSVRC2016/features_2560/n01776313.mat
# 79 C:/Datasets/ILSVRC2016/features_2560/n01784675.mat
# 80 C:/Datasets/ILSVRC2016/features_2560/n01795545.mat
# 81 C:/Datasets/ILSVRC2016/features_2560/n01796340.mat
# 82 C:/Datasets/ILSVRC2016/features_2560/n01797886.mat
# 83 C:/Datasets/ILSVRC2016/features_2560/n01798484.mat
# 84 C:/Datasets/ILSVRC2016/features_2560/n01806143.mat
# 85 C:/Datasets/ILSVRC2016/features_2560/n01806567.mat
# 86 C:/Datasets/ILSVRC2016/features_2560/n01807496.mat
# 87 C:/Datasets/ILSVRC2016/features_2560/n01817953.mat
# 88 C:/Datasets/ILSVRC2016/features_2560/n01818515.mat
# 89 C:/Datasets/ILSVRC2016/features_2560/n01819313.mat
# 90 C:/Datasets/ILSVRC2016/features_2560/n01820546.mat
# 91 C:/Datasets/ILSVRC2016/features_2560/n01824575.mat
# 92 C:/Datasets/ILSVRC2016/features_2560/n01828970.mat
# 93 C:/Datasets/ILSVRC2016/features_2560/n01829413.mat
# 94 C:/Datasets/ILSVRC2016/features_2560/n01833805.mat
# 95 C:/Datasets/ILSVRC2016/features_2560/n01843065.mat
# 96 C:/Datasets/ILSVRC2016/features_2560/n01843383.mat
# 97 C:/Datasets/ILSVRC2016/features_2560/n01847000.mat
# 98 C:/Datasets/ILSVRC2016/features_2560/n01855032.mat
# 99 C:/Datasets/ILSVRC2016/features_2560/n01855672.mat
# 100 C:/Datasets/ILSVRC2016/features_2560/n01860187.mat
# 101 C:/Datasets/ILSVRC2016/features_2560/n01871265.mat
# 102 C:/Datasets/ILSVRC2016/features_2560/n01872401.mat
# 103 C:/Datasets/ILSVRC2016/features_2560/n01873310.mat
# 104 C:/Datasets/ILSVRC2016/features_2560/n01877812.mat
# 105 C:/Datasets/ILSVRC2016/features_2560/n01882714.mat
# 106 C:/Datasets/ILSVRC2016/features_2560/n01883070.mat
# 107 C:/Datasets/ILSVRC2016/features_2560/n01910747.mat
# 108 C:/Datasets/ILSVRC2016/features_2560/n01914609.mat
# 109 C:/Datasets/ILSVRC2016/features_2560/n01917289.mat
# 110 C:/Datasets/ILSVRC2016/features_2560/n01924916.mat
# 111 C:/Datasets/ILSVRC2016/features_2560/n01930112.mat
# 112 C:/Datasets/ILSVRC2016/features_2560/n01943899.mat
# 113 C:/Datasets/ILSVRC2016/features_2560/n01944390.mat
# 114 C:/Datasets/ILSVRC2016/features_2560/n01945685.mat
# 115 C:/Datasets/ILSVRC2016/features_2560/n01950731.mat
# 116 C:/Datasets/ILSVRC2016/features_2560/n01955084.mat
# 117 C:/Datasets/ILSVRC2016/features_2560/n01968897.mat
# 118 C:/Datasets/ILSVRC2016/features_2560/n01978287.mat
# 119 C:/Datasets/ILSVRC2016/features_2560/n01978455.mat
# 120 C:/Datasets/ILSVRC2016/features_2560/n01980166.mat
# 121 C:/Datasets/ILSVRC2016/features_2560/n01981276.mat
# 122 C:/Datasets/ILSVRC2016/features_2560/n01983481.mat
# 123 C:/Datasets/ILSVRC2016/features_2560/n01984695.mat
# 124 C:/Datasets/ILSVRC2016/features_2560/n01985128.mat
# 125 C:/Datasets/ILSVRC2016/features_2560/n01986214.mat
# 126 C:/Datasets/ILSVRC2016/features_2560/n01990800.mat
# 127 C:/Datasets/ILSVRC2016/features_2560/n02002556.mat
# 128 C:/Datasets/ILSVRC2016/features_2560/n02002724.mat
# 129 C:/Datasets/ILSVRC2016/features_2560/n02006656.mat
# 130 C:/Datasets/ILSVRC2016/features_2560/n02007558.mat
# 131 C:/Datasets/ILSVRC2016/features_2560/n02009229.mat
# 132 C:/Datasets/ILSVRC2016/features_2560/n02009912.mat
# 133 C:/Datasets/ILSVRC2016/features_2560/n02011460.mat
# 134 C:/Datasets/ILSVRC2016/features_2560/n02012849.mat
# 135 C:/Datasets/ILSVRC2016/features_2560/n02013706.mat
# 136 C:/Datasets/ILSVRC2016/features_2560/n02017213.mat
# 137 C:/Datasets/ILSVRC2016/features_2560/n02018207.mat
# 138 C:/Datasets/ILSVRC2016/features_2560/n02018795.mat
# 139 C:/Datasets/ILSVRC2016/features_2560/n02025239.mat
# 140 C:/Datasets/ILSVRC2016/features_2560/n02027492.mat
# 141 C:/Datasets/ILSVRC2016/features_2560/n02028035.mat
# 142 C:/Datasets/ILSVRC2016/features_2560/n02033041.mat
# 143 C:/Datasets/ILSVRC2016/features_2560/n02037110.mat
# 144 C:/Datasets/ILSVRC2016/features_2560/n02051845.mat
# 145 C:/Datasets/ILSVRC2016/features_2560/n02056570.mat
# 146 C:/Datasets/ILSVRC2016/features_2560/n02058221.mat
# 147 C:/Datasets/ILSVRC2016/features_2560/n02066245.mat
# 148 C:/Datasets/ILSVRC2016/features_2560/n02071294.mat
# 149 C:/Datasets/ILSVRC2016/features_2560/n02074367.mat
# 150 C:/Datasets/ILSVRC2016/features_2560/n02077923.mat
# 151 C:/Datasets/ILSVRC2016/features_2560/n02085620.mat
# 152 C:/Datasets/ILSVRC2016/features_2560/n02085782.mat
# 153 C:/Datasets/ILSVRC2016/features_2560/n02085936.mat
# 154 C:/Datasets/ILSVRC2016/features_2560/n02086079.mat
# 155 C:/Datasets/ILSVRC2016/features_2560/n02086240.mat
# 156 C:/Datasets/ILSVRC2016/features_2560/n02086646.mat
# 157 C:/Datasets/ILSVRC2016/features_2560/n02086910.mat
# 158 C:/Datasets/ILSVRC2016/features_2560/n02087046.mat
# 159 C:/Datasets/ILSVRC2016/features_2560/n02087394.mat
# 160 C:/Datasets/ILSVRC2016/features_2560/n02088094.mat
# 161 C:/Datasets/ILSVRC2016/features_2560/n02088238.mat
# 162 C:/Datasets/ILSVRC2016/features_2560/n02088364.mat
# 163 C:/Datasets/ILSVRC2016/features_2560/n02088466.mat
# 164 C:/Datasets/ILSVRC2016/features_2560/n02088632.mat
# 165 C:/Datasets/ILSVRC2016/features_2560/n02089078.mat
# 166 C:/Datasets/ILSVRC2016/features_2560/n02089867.mat
# 167 C:/Datasets/ILSVRC2016/features_2560/n02089973.mat
# 168 C:/Datasets/ILSVRC2016/features_2560/n02090379.mat
# 169 C:/Datasets/ILSVRC2016/features_2560/n02090622.mat
# 170 C:/Datasets/ILSVRC2016/features_2560/n02090721.mat
# 171 C:/Datasets/ILSVRC2016/features_2560/n02091032.mat
# 172 C:/Datasets/ILSVRC2016/features_2560/n02091134.mat
# 173 C:/Datasets/ILSVRC2016/features_2560/n02091244.mat
# 174 C:/Datasets/ILSVRC2016/features_2560/n02091467.mat
# 175 C:/Datasets/ILSVRC2016/features_2560/n02091635.mat
# 176 C:/Datasets/ILSVRC2016/features_2560/n02091831.mat
# 177 C:/Datasets/ILSVRC2016/features_2560/n02092002.mat
# 178 C:/Datasets/ILSVRC2016/features_2560/n02092339.mat
# 179 C:/Datasets/ILSVRC2016/features_2560/n02093256.mat
# 180 C:/Datasets/ILSVRC2016/features_2560/n02093428.mat
# 181 C:/Datasets/ILSVRC2016/features_2560/n02093647.mat
# 182 C:/Datasets/ILSVRC2016/features_2560/n02093754.mat
# 183 C:/Datasets/ILSVRC2016/features_2560/n02093859.mat
# 184 C:/Datasets/ILSVRC2016/features_2560/n02093991.mat
# 185 C:/Datasets/ILSVRC2016/features_2560/n02094114.mat
# 186 C:/Datasets/ILSVRC2016/features_2560/n02094258.mat
# 187 C:/Datasets/ILSVRC2016/features_2560/n02094433.mat
# 188 C:/Datasets/ILSVRC2016/features_2560/n02095314.mat
# 189 C:/Datasets/ILSVRC2016/features_2560/n02095570.mat
# 190 C:/Datasets/ILSVRC2016/features_2560/n02095889.mat
# 191 C:/Datasets/ILSVRC2016/features_2560/n02096051.mat
# 192 C:/Datasets/ILSVRC2016/features_2560/n02096177.mat
# 193 C:/Datasets/ILSVRC2016/features_2560/n02096294.mat
# 194 C:/Datasets/ILSVRC2016/features_2560/n02096437.mat
# 195 C:/Datasets/ILSVRC2016/features_2560/n02096585.mat
# 196 C:/Datasets/ILSVRC2016/features_2560/n02097047.mat
# 197 C:/Datasets/ILSVRC2016/features_2560/n02097130.mat
# 198 C:/Datasets/ILSVRC2016/features_2560/n02097209.mat
# 199 C:/Datasets/ILSVRC2016/features_2560/n02097298.mat
# 200 C:/Datasets/ILSVRC2016/features_2560/n02097474.mat
# 201 C:/Datasets/ILSVRC2016/features_2560/n02097658.mat
# 202 C:/Datasets/ILSVRC2016/features_2560/n02098105.mat
# 203 C:/Datasets/ILSVRC2016/features_2560/n02098286.mat
# 204 C:/Datasets/ILSVRC2016/features_2560/n02098413.mat
# 205 C:/Datasets/ILSVRC2016/features_2560/n02099267.mat
# 206 C:/Datasets/ILSVRC2016/features_2560/n02099429.mat
# 207 C:/Datasets/ILSVRC2016/features_2560/n02099601.mat
# 208 C:/Datasets/ILSVRC2016/features_2560/n02099712.mat
# 209 C:/Datasets/ILSVRC2016/features_2560/n02099849.mat
# 210 C:/Datasets/ILSVRC2016/features_2560/n02100236.mat
# 211 C:/Datasets/ILSVRC2016/features_2560/n02100583.mat
# 212 C:/Datasets/ILSVRC2016/features_2560/n02100735.mat
# 213 C:/Datasets/ILSVRC2016/features_2560/n02100877.mat
# 214 C:/Datasets/ILSVRC2016/features_2560/n02101006.mat
# 215 C:/Datasets/ILSVRC2016/features_2560/n02101388.mat
# 216 C:/Datasets/ILSVRC2016/features_2560/n02101556.mat
# 217 C:/Datasets/ILSVRC2016/features_2560/n02102040.mat
# 218 C:/Datasets/ILSVRC2016/features_2560/n02102177.mat
# 219 C:/Datasets/ILSVRC2016/features_2560/n02102318.mat
# 220 C:/Datasets/ILSVRC2016/features_2560/n02102480.mat
# 221 C:/Datasets/ILSVRC2016/features_2560/n02102973.mat
# 222 C:/Datasets/ILSVRC2016/features_2560/n02104029.mat
# 223 C:/Datasets/ILSVRC2016/features_2560/n02104365.mat
# 224 C:/Datasets/ILSVRC2016/features_2560/n02105056.mat
# 225 C:/Datasets/ILSVRC2016/features_2560/n02105162.mat
# 226 C:/Datasets/ILSVRC2016/features_2560/n02105251.mat
# 227 C:/Datasets/ILSVRC2016/features_2560/n02105412.mat
# 228 C:/Datasets/ILSVRC2016/features_2560/n02105505.mat
# 229 C:/Datasets/ILSVRC2016/features_2560/n02105641.mat
# 230 C:/Datasets/ILSVRC2016/features_2560/n02105855.mat
# 231 C:/Datasets/ILSVRC2016/features_2560/n02106030.mat
# 232 C:/Datasets/ILSVRC2016/features_2560/n02106166.mat
# 233 C:/Datasets/ILSVRC2016/features_2560/n02106382.mat
# 234 C:/Datasets/ILSVRC2016/features_2560/n02106550.mat
# 235 C:/Datasets/ILSVRC2016/features_2560/n02106662.mat
# 236 C:/Datasets/ILSVRC2016/features_2560/n02107142.mat
# 237 C:/Datasets/ILSVRC2016/features_2560/n02107312.mat
# 238 C:/Datasets/ILSVRC2016/features_2560/n02107574.mat
# 239 C:/Datasets/ILSVRC2016/features_2560/n02107683.mat
# 240 C:/Datasets/ILSVRC2016/features_2560/n02107908.mat
# 241 C:/Datasets/ILSVRC2016/features_2560/n02108000.mat
# 242 C:/Datasets/ILSVRC2016/features_2560/n02108089.mat
# 243 C:/Datasets/ILSVRC2016/features_2560/n02108422.mat
# 244 C:/Datasets/ILSVRC2016/features_2560/n02108551.mat
# 245 C:/Datasets/ILSVRC2016/features_2560/n02108915.mat
# 246 C:/Datasets/ILSVRC2016/features_2560/n02109047.mat
# 247 C:/Datasets/ILSVRC2016/features_2560/n02109525.mat
# 248 C:/Datasets/ILSVRC2016/features_2560/n02109961.mat
# 249 C:/Datasets/ILSVRC2016/features_2560/n02110063.mat
# 250 C:/Datasets/ILSVRC2016/features_2560/n02110185.mat
# 251 C:/Datasets/ILSVRC2016/features_2560/n02110341.mat
# 252 C:/Datasets/ILSVRC2016/features_2560/n02110627.mat
# 253 C:/Datasets/ILSVRC2016/features_2560/n02110806.mat
# 254 C:/Datasets/ILSVRC2016/features_2560/n02110958.mat
# 255 C:/Datasets/ILSVRC2016/features_2560/n02111129.mat
# 256 C:/Datasets/ILSVRC2016/features_2560/n02111277.mat
# 257 C:/Datasets/ILSVRC2016/features_2560/n02111500.mat
# 258 C:/Datasets/ILSVRC2016/features_2560/n02111889.mat
# 259 C:/Datasets/ILSVRC2016/features_2560/n02112018.mat
# 260 C:/Datasets/ILSVRC2016/features_2560/n02112137.mat
# 261 C:/Datasets/ILSVRC2016/features_2560/n02112350.mat
# 262 C:/Datasets/ILSVRC2016/features_2560/n02112706.mat
# 263 C:/Datasets/ILSVRC2016/features_2560/n02113023.mat
# 264 C:/Datasets/ILSVRC2016/features_2560/n02113186.mat
# 265 C:/Datasets/ILSVRC2016/features_2560/n02113624.mat
# 266 C:/Datasets/ILSVRC2016/features_2560/n02113712.mat
# 267 C:/Datasets/ILSVRC2016/features_2560/n02113799.mat
# 268 C:/Datasets/ILSVRC2016/features_2560/n02113978.mat
# 269 C:/Datasets/ILSVRC2016/features_2560/n02114367.mat
# 270 C:/Datasets/ILSVRC2016/features_2560/n02114548.mat
# 271 C:/Datasets/ILSVRC2016/features_2560/n02114712.mat
# 272 C:/Datasets/ILSVRC2016/features_2560/n02114855.mat
# 273 C:/Datasets/ILSVRC2016/features_2560/n02115641.mat
# 274 C:/Datasets/ILSVRC2016/features_2560/n02115913.mat
# 275 C:/Datasets/ILSVRC2016/features_2560/n02116738.mat
# 276 C:/Datasets/ILSVRC2016/features_2560/n02117135.mat
# 277 C:/Datasets/ILSVRC2016/features_2560/n02119022.mat
# 278 C:/Datasets/ILSVRC2016/features_2560/n02119789.mat
# 279 C:/Datasets/ILSVRC2016/features_2560/n02120079.mat
# 280 C:/Datasets/ILSVRC2016/features_2560/n02120505.mat
# 281 C:/Datasets/ILSVRC2016/features_2560/n02123045.mat
# 282 C:/Datasets/ILSVRC2016/features_2560/n02123159.mat
# 283 C:/Datasets/ILSVRC2016/features_2560/n02123394.mat
# 284 C:/Datasets/ILSVRC2016/features_2560/n02123597.mat
# 285 C:/Datasets/ILSVRC2016/features_2560/n02124075.mat
# 286 C:/Datasets/ILSVRC2016/features_2560/n02125311.mat
# 287 C:/Datasets/ILSVRC2016/features_2560/n02127052.mat
# 288 C:/Datasets/ILSVRC2016/features_2560/n02128385.mat
# 289 C:/Datasets/ILSVRC2016/features_2560/n02128757.mat
# 290 C:/Datasets/ILSVRC2016/features_2560/n02128925.mat
# 291 C:/Datasets/ILSVRC2016/features_2560/n02129165.mat
# 292 C:/Datasets/ILSVRC2016/features_2560/n02129604.mat
# 293 C:/Datasets/ILSVRC2016/features_2560/n02130308.mat
# 294 C:/Datasets/ILSVRC2016/features_2560/n02132136.mat
# 295 C:/Datasets/ILSVRC2016/features_2560/n02133161.mat
# 296 C:/Datasets/ILSVRC2016/features_2560/n02134084.mat
# 297 C:/Datasets/ILSVRC2016/features_2560/n02134418.mat
# 298 C:/Datasets/ILSVRC2016/features_2560/n02137549.mat
# 299 C:/Datasets/ILSVRC2016/features_2560/n02138441.mat
# 300 C:/Datasets/ILSVRC2016/features_2560/n02165105.mat
# 301 C:/Datasets/ILSVRC2016/features_2560/n02165456.mat
# 302 C:/Datasets/ILSVRC2016/features_2560/n02167151.mat
# 303 C:/Datasets/ILSVRC2016/features_2560/n02168699.mat
# 304 C:/Datasets/ILSVRC2016/features_2560/n02169497.mat
# 305 C:/Datasets/ILSVRC2016/features_2560/n02172182.mat
# 306 C:/Datasets/ILSVRC2016/features_2560/n02174001.mat
# 307 C:/Datasets/ILSVRC2016/features_2560/n02177972.mat
# 308 C:/Datasets/ILSVRC2016/features_2560/n02190166.mat
# 309 C:/Datasets/ILSVRC2016/features_2560/n02206856.mat
# 310 C:/Datasets/ILSVRC2016/features_2560/n02219486.mat
# 311 C:/Datasets/ILSVRC2016/features_2560/n02226429.mat
# 312 C:/Datasets/ILSVRC2016/features_2560/n02229544.mat
# 313 C:/Datasets/ILSVRC2016/features_2560/n02231487.mat
# 314 C:/Datasets/ILSVRC2016/features_2560/n02233338.mat
# 315 C:/Datasets/ILSVRC2016/features_2560/n02236044.mat
# 316 C:/Datasets/ILSVRC2016/features_2560/n02256656.mat
# 317 C:/Datasets/ILSVRC2016/features_2560/n02259212.mat
# 318 C:/Datasets/ILSVRC2016/features_2560/n02264363.mat
# 319 C:/Datasets/ILSVRC2016/features_2560/n02268443.mat
# 320 C:/Datasets/ILSVRC2016/features_2560/n02268853.mat
# 321 C:/Datasets/ILSVRC2016/features_2560/n02276258.mat
# 322 C:/Datasets/ILSVRC2016/features_2560/n02277742.mat
# 323 C:/Datasets/ILSVRC2016/features_2560/n02279972.mat
# 324 C:/Datasets/ILSVRC2016/features_2560/n02280649.mat
# 325 C:/Datasets/ILSVRC2016/features_2560/n02281406.mat
# 326 C:/Datasets/ILSVRC2016/features_2560/n02281787.mat
# 327 C:/Datasets/ILSVRC2016/features_2560/n02317335.mat
# 328 C:/Datasets/ILSVRC2016/features_2560/n02319095.mat
# 329 C:/Datasets/ILSVRC2016/features_2560/n02321529.mat
# 330 C:/Datasets/ILSVRC2016/features_2560/n02325366.mat
# 331 C:/Datasets/ILSVRC2016/features_2560/n02326432.mat
# 332 C:/Datasets/ILSVRC2016/features_2560/n02328150.mat
# 333 C:/Datasets/ILSVRC2016/features_2560/n02342885.mat
# 334 C:/Datasets/ILSVRC2016/features_2560/n02346627.mat
# 335 C:/Datasets/ILSVRC2016/features_2560/n02356798.mat
# 336 C:/Datasets/ILSVRC2016/features_2560/n02361337.mat
# 337 C:/Datasets/ILSVRC2016/features_2560/n02363005.mat
# 338 C:/Datasets/ILSVRC2016/features_2560/n02364673.mat
# 339 C:/Datasets/ILSVRC2016/features_2560/n02389026.mat
# 340 C:/Datasets/ILSVRC2016/features_2560/n02391049.mat
# 341 C:/Datasets/ILSVRC2016/features_2560/n02395406.mat
# 342 C:/Datasets/ILSVRC2016/features_2560/n02396427.mat
# 343 C:/Datasets/ILSVRC2016/features_2560/n02397096.mat
# 344 C:/Datasets/ILSVRC2016/features_2560/n02398521.mat
# 345 C:/Datasets/ILSVRC2016/features_2560/n02403003.mat
# 346 C:/Datasets/ILSVRC2016/features_2560/n02408429.mat
# 347 C:/Datasets/ILSVRC2016/features_2560/n02410509.mat
# 348 C:/Datasets/ILSVRC2016/features_2560/n02412080.mat
# 349 C:/Datasets/ILSVRC2016/features_2560/n02415577.mat
# 350 C:/Datasets/ILSVRC2016/features_2560/n02417914.mat
# 351 C:/Datasets/ILSVRC2016/features_2560/n02422106.mat
# 352 C:/Datasets/ILSVRC2016/features_2560/n02422699.mat
# 353 C:/Datasets/ILSVRC2016/features_2560/n02423022.mat
# 354 C:/Datasets/ILSVRC2016/features_2560/n02437312.mat
# 355 C:/Datasets/ILSVRC2016/features_2560/n02437616.mat
# 356 C:/Datasets/ILSVRC2016/features_2560/n02441942.mat
# 357 C:/Datasets/ILSVRC2016/features_2560/n02442845.mat
# 358 C:/Datasets/ILSVRC2016/features_2560/n02443114.mat
# 359 C:/Datasets/ILSVRC2016/features_2560/n02443484.mat
# 360 C:/Datasets/ILSVRC2016/features_2560/n02444819.mat
# 361 C:/Datasets/ILSVRC2016/features_2560/n02445715.mat
# 362 C:/Datasets/ILSVRC2016/features_2560/n02447366.mat
# 363 C:/Datasets/ILSVRC2016/features_2560/n02454379.mat
# 364 C:/Datasets/ILSVRC2016/features_2560/n02457408.mat
# 365 C:/Datasets/ILSVRC2016/features_2560/n02480495.mat
# 366 C:/Datasets/ILSVRC2016/features_2560/n02480855.mat
# 367 C:/Datasets/ILSVRC2016/features_2560/n02481823.mat
# 368 C:/Datasets/ILSVRC2016/features_2560/n02483362.mat
# 369 C:/Datasets/ILSVRC2016/features_2560/n02483708.mat
# 370 C:/Datasets/ILSVRC2016/features_2560/n02484975.mat
# 371 C:/Datasets/ILSVRC2016/features_2560/n02486261.mat
# 372 C:/Datasets/ILSVRC2016/features_2560/n02486410.mat
# 373 C:/Datasets/ILSVRC2016/features_2560/n02487347.mat
# 374 C:/Datasets/ILSVRC2016/features_2560/n02488291.mat
# 375 C:/Datasets/ILSVRC2016/features_2560/n02488702.mat
# 376 C:/Datasets/ILSVRC2016/features_2560/n02489166.mat
# 377 C:/Datasets/ILSVRC2016/features_2560/n02490219.mat
# 378 C:/Datasets/ILSVRC2016/features_2560/n02492035.mat
# 379 C:/Datasets/ILSVRC2016/features_2560/n02492660.mat
# 380 C:/Datasets/ILSVRC2016/features_2560/n02493509.mat
# 381 C:/Datasets/ILSVRC2016/features_2560/n02493793.mat
# 382 C:/Datasets/ILSVRC2016/features_2560/n02494079.mat
# 383 C:/Datasets/ILSVRC2016/features_2560/n02497673.mat
# 384 C:/Datasets/ILSVRC2016/features_2560/n02500267.mat
# 385 C:/Datasets/ILSVRC2016/features_2560/n02504013.mat
# 386 C:/Datasets/ILSVRC2016/features_2560/n02504458.mat
# 387 C:/Datasets/ILSVRC2016/features_2560/n02509815.mat
# 388 C:/Datasets/ILSVRC2016/features_2560/n02510455.mat
# 389 C:/Datasets/ILSVRC2016/features_2560/n02514041.mat
# 390 C:/Datasets/ILSVRC2016/features_2560/n02526121.mat
# 391 C:/Datasets/ILSVRC2016/features_2560/n02536864.mat
# 392 C:/Datasets/ILSVRC2016/features_2560/n02606052.mat
# 393 C:/Datasets/ILSVRC2016/features_2560/n02607072.mat
# 394 C:/Datasets/ILSVRC2016/features_2560/n02640242.mat
# 395 C:/Datasets/ILSVRC2016/features_2560/n02641379.mat
# 396 C:/Datasets/ILSVRC2016/features_2560/n02643566.mat
# 397 C:/Datasets/ILSVRC2016/features_2560/n02655020.mat
# 398 C:/Datasets/ILSVRC2016/features_2560/n02666196.mat
# 399 C:/Datasets/ILSVRC2016/features_2560/n02667093.mat
# 400 C:/Datasets/ILSVRC2016/features_2560/n02669723.mat
# 401 C:/Datasets/ILSVRC2016/features_2560/n02672831.mat
# 402 C:/Datasets/ILSVRC2016/features_2560/n02676566.mat
# 403 C:/Datasets/ILSVRC2016/features_2560/n02687172.mat
# 404 C:/Datasets/ILSVRC2016/features_2560/n02690373.mat
# 405 C:/Datasets/ILSVRC2016/features_2560/n02692877.mat
# 406 C:/Datasets/ILSVRC2016/features_2560/n02699494.mat
# 407 C:/Datasets/ILSVRC2016/features_2560/n02701002.mat
# 408 C:/Datasets/ILSVRC2016/features_2560/n02704792.mat
# 409 C:/Datasets/ILSVRC2016/features_2560/n02708093.mat
# 410 C:/Datasets/ILSVRC2016/features_2560/n02727426.mat
# 411 C:/Datasets/ILSVRC2016/features_2560/n02730930.mat
# 412 C:/Datasets/ILSVRC2016/features_2560/n02747177.mat
# 413 C:/Datasets/ILSVRC2016/features_2560/n02749479.mat
# 414 C:/Datasets/ILSVRC2016/features_2560/n02769748.mat
# 415 C:/Datasets/ILSVRC2016/features_2560/n02776631.mat
# 416 C:/Datasets/ILSVRC2016/features_2560/n02777292.mat
# 417 C:/Datasets/ILSVRC2016/features_2560/n02782093.mat
# 418 C:/Datasets/ILSVRC2016/features_2560/n02783161.mat
# 419 C:/Datasets/ILSVRC2016/features_2560/n02786058.mat
# 420 C:/Datasets/ILSVRC2016/features_2560/n02787622.mat
# 421 C:/Datasets/ILSVRC2016/features_2560/n02788148.mat
# 422 C:/Datasets/ILSVRC2016/features_2560/n02790996.mat
# 423 C:/Datasets/ILSVRC2016/features_2560/n02791124.mat
# 424 C:/Datasets/ILSVRC2016/features_2560/n02791270.mat
# 425 C:/Datasets/ILSVRC2016/features_2560/n02793495.mat
# 426 C:/Datasets/ILSVRC2016/features_2560/n02794156.mat
# 427 C:/Datasets/ILSVRC2016/features_2560/n02795169.mat
# 428 C:/Datasets/ILSVRC2016/features_2560/n02797295.mat
# 429 C:/Datasets/ILSVRC2016/features_2560/n02799071.mat
# 430 C:/Datasets/ILSVRC2016/features_2560/n02802426.mat
# 431 C:/Datasets/ILSVRC2016/features_2560/n02804414.mat
# 432 C:/Datasets/ILSVRC2016/features_2560/n02804610.mat
# 433 C:/Datasets/ILSVRC2016/features_2560/n02807133.mat
# 434 C:/Datasets/ILSVRC2016/features_2560/n02808304.mat
# 435 C:/Datasets/ILSVRC2016/features_2560/n02808440.mat
# 436 C:/Datasets/ILSVRC2016/features_2560/n02814533.mat
# 437 C:/Datasets/ILSVRC2016/features_2560/n02814860.mat
# 438 C:/Datasets/ILSVRC2016/features_2560/n02815834.mat
# 439 C:/Datasets/ILSVRC2016/features_2560/n02817516.mat
# 440 C:/Datasets/ILSVRC2016/features_2560/n02823428.mat
# 441 C:/Datasets/ILSVRC2016/features_2560/n02823750.mat
# 442 C:/Datasets/ILSVRC2016/features_2560/n02825657.mat
# 443 C:/Datasets/ILSVRC2016/features_2560/n02834397.mat
# 444 C:/Datasets/ILSVRC2016/features_2560/n02835271.mat
# 445 C:/Datasets/ILSVRC2016/features_2560/n02837789.mat
# 446 C:/Datasets/ILSVRC2016/features_2560/n02840245.mat
# 447 C:/Datasets/ILSVRC2016/features_2560/n02841315.mat
# 448 C:/Datasets/ILSVRC2016/features_2560/n02843684.mat
# 449 C:/Datasets/ILSVRC2016/features_2560/n02859443.mat
# 450 C:/Datasets/ILSVRC2016/features_2560/n02860847.mat
# 451 C:/Datasets/ILSVRC2016/features_2560/n02865351.mat
# 452 C:/Datasets/ILSVRC2016/features_2560/n02869837.mat
# 453 C:/Datasets/ILSVRC2016/features_2560/n02870880.mat
# 454 C:/Datasets/ILSVRC2016/features_2560/n02871525.mat
# 455 C:/Datasets/ILSVRC2016/features_2560/n02877765.mat
# 456 C:/Datasets/ILSVRC2016/features_2560/n02879718.mat
# 457 C:/Datasets/ILSVRC2016/features_2560/n02883205.mat
# 458 C:/Datasets/ILSVRC2016/features_2560/n02892201.mat
# 459 C:/Datasets/ILSVRC2016/features_2560/n02892767.mat
# 460 C:/Datasets/ILSVRC2016/features_2560/n02894605.mat
# 461 C:/Datasets/ILSVRC2016/features_2560/n02895154.mat
# 462 C:/Datasets/ILSVRC2016/features_2560/n02906734.mat
# 463 C:/Datasets/ILSVRC2016/features_2560/n02909870.mat
# 464 C:/Datasets/ILSVRC2016/features_2560/n02910353.mat
# 465 C:/Datasets/ILSVRC2016/features_2560/n02916936.mat
# 466 C:/Datasets/ILSVRC2016/features_2560/n02917067.mat
# 467 C:/Datasets/ILSVRC2016/features_2560/n02927161.mat
# 468 C:/Datasets/ILSVRC2016/features_2560/n02930766.mat
# 469 C:/Datasets/ILSVRC2016/features_2560/n02939185.mat
# 470 C:/Datasets/ILSVRC2016/features_2560/n02948072.mat
# 471 C:/Datasets/ILSVRC2016/features_2560/n02950826.mat
# 472 C:/Datasets/ILSVRC2016/features_2560/n02951358.mat
# 473 C:/Datasets/ILSVRC2016/features_2560/n02951585.mat
# 474 C:/Datasets/ILSVRC2016/features_2560/n02963159.mat
# 475 C:/Datasets/ILSVRC2016/features_2560/n02965783.mat
# 476 C:/Datasets/ILSVRC2016/features_2560/n02966193.mat
# 477 C:/Datasets/ILSVRC2016/features_2560/n02966687.mat
# 478 C:/Datasets/ILSVRC2016/features_2560/n02971356.mat
# 479 C:/Datasets/ILSVRC2016/features_2560/n02974003.mat
# 480 C:/Datasets/ILSVRC2016/features_2560/n02977058.mat
# 481 C:/Datasets/ILSVRC2016/features_2560/n02978881.mat
# 482 C:/Datasets/ILSVRC2016/features_2560/n02979186.mat
# 483 C:/Datasets/ILSVRC2016/features_2560/n02980441.mat
# 484 C:/Datasets/ILSVRC2016/features_2560/n02981792.mat
# 485 C:/Datasets/ILSVRC2016/features_2560/n02988304.mat
# 486 C:/Datasets/ILSVRC2016/features_2560/n02992211.mat
# 487 C:/Datasets/ILSVRC2016/features_2560/n02992529.mat
# 488 C:/Datasets/ILSVRC2016/features_2560/n02999410.mat
# 489 C:/Datasets/ILSVRC2016/features_2560/n03000134.mat
# 490 C:/Datasets/ILSVRC2016/features_2560/n03000247.mat
# 491 C:/Datasets/ILSVRC2016/features_2560/n03000684.mat
# 492 C:/Datasets/ILSVRC2016/features_2560/n03014705.mat
# 493 C:/Datasets/ILSVRC2016/features_2560/n03016953.mat
# 494 C:/Datasets/ILSVRC2016/features_2560/n03017168.mat
# 495 C:/Datasets/ILSVRC2016/features_2560/n03018349.mat
# 496 C:/Datasets/ILSVRC2016/features_2560/n03026506.mat
# 497 C:/Datasets/ILSVRC2016/features_2560/n03028079.mat
# 498 C:/Datasets/ILSVRC2016/features_2560/n03032252.mat
# 499 C:/Datasets/ILSVRC2016/features_2560/n03041632.mat
# 500 C:/Datasets/ILSVRC2016/features_2560/n03042490.mat
# 501 C:/Datasets/ILSVRC2016/features_2560/n03045698.mat
# 502 C:/Datasets/ILSVRC2016/features_2560/n03047690.mat
# 503 C:/Datasets/ILSVRC2016/features_2560/n03062245.mat
# 504 C:/Datasets/ILSVRC2016/features_2560/n03063599.mat
# 505 C:/Datasets/ILSVRC2016/features_2560/n03063689.mat
# 506 C:/Datasets/ILSVRC2016/features_2560/n03065424.mat
# 507 C:/Datasets/ILSVRC2016/features_2560/n03075370.mat
# 508 C:/Datasets/ILSVRC2016/features_2560/n03085013.mat
# 509 C:/Datasets/ILSVRC2016/features_2560/n03089624.mat
# 510 C:/Datasets/ILSVRC2016/features_2560/n03095699.mat
# 511 C:/Datasets/ILSVRC2016/features_2560/n03100240.mat
# 512 C:/Datasets/ILSVRC2016/features_2560/n03109150.mat
# 513 C:/Datasets/ILSVRC2016/features_2560/n03110669.mat
# 514 C:/Datasets/ILSVRC2016/features_2560/n03124043.mat
# 515 C:/Datasets/ILSVRC2016/features_2560/n03124170.mat
# 516 C:/Datasets/ILSVRC2016/features_2560/n03125729.mat
# 517 C:/Datasets/ILSVRC2016/features_2560/n03126707.mat
# 518 C:/Datasets/ILSVRC2016/features_2560/n03127747.mat
# 519 C:/Datasets/ILSVRC2016/features_2560/n03127925.mat
# 520 C:/Datasets/ILSVRC2016/features_2560/n03131574.mat
# 521 C:/Datasets/ILSVRC2016/features_2560/n03133878.mat
# 522 C:/Datasets/ILSVRC2016/features_2560/n03134739.mat
# 523 C:/Datasets/ILSVRC2016/features_2560/n03141823.mat
# 524 C:/Datasets/ILSVRC2016/features_2560/n03146219.mat
# 525 C:/Datasets/ILSVRC2016/features_2560/n03160309.mat
# 526 C:/Datasets/ILSVRC2016/features_2560/n03179701.mat
# 527 C:/Datasets/ILSVRC2016/features_2560/n03180011.mat
# 528 C:/Datasets/ILSVRC2016/features_2560/n03187595.mat
# 529 C:/Datasets/ILSVRC2016/features_2560/n03188531.mat
# 530 C:/Datasets/ILSVRC2016/features_2560/n03196217.mat
# 531 C:/Datasets/ILSVRC2016/features_2560/n03197337.mat
# 532 C:/Datasets/ILSVRC2016/features_2560/n03201208.mat
# 533 C:/Datasets/ILSVRC2016/features_2560/n03207743.mat
# 534 C:/Datasets/ILSVRC2016/features_2560/n03207941.mat
# 535 C:/Datasets/ILSVRC2016/features_2560/n03208938.mat
# 536 C:/Datasets/ILSVRC2016/features_2560/n03216828.mat
# 537 C:/Datasets/ILSVRC2016/features_2560/n03218198.mat
# 538 C:/Datasets/ILSVRC2016/features_2560/n03220513.mat
# 539 C:/Datasets/ILSVRC2016/features_2560/n03223299.mat
# 540 C:/Datasets/ILSVRC2016/features_2560/n03240683.mat
# 541 C:/Datasets/ILSVRC2016/features_2560/n03249569.mat
# 542 C:/Datasets/ILSVRC2016/features_2560/n03250847.mat
# 543 C:/Datasets/ILSVRC2016/features_2560/n03255030.mat
# 544 C:/Datasets/ILSVRC2016/features_2560/n03259280.mat
# 545 C:/Datasets/ILSVRC2016/features_2560/n03271574.mat
# 546 C:/Datasets/ILSVRC2016/features_2560/n03272010.mat
# 547 C:/Datasets/ILSVRC2016/features_2560/n03272562.mat
# 548 C:/Datasets/ILSVRC2016/features_2560/n03290653.mat
# 549 C:/Datasets/ILSVRC2016/features_2560/n03291819.mat
# 550 C:/Datasets/ILSVRC2016/features_2560/n03297495.mat
# 551 C:/Datasets/ILSVRC2016/features_2560/n03314780.mat
# 552 C:/Datasets/ILSVRC2016/features_2560/n03325584.mat
# 553 C:/Datasets/ILSVRC2016/features_2560/n03337140.mat
# 554 C:/Datasets/ILSVRC2016/features_2560/n03344393.mat
# 555 C:/Datasets/ILSVRC2016/features_2560/n03345487.mat
# 556 C:/Datasets/ILSVRC2016/features_2560/n03347037.mat
# 557 C:/Datasets/ILSVRC2016/features_2560/n03355925.mat
# 558 C:/Datasets/ILSVRC2016/features_2560/n03372029.mat
# 559 C:/Datasets/ILSVRC2016/features_2560/n03376595.mat
# 560 C:/Datasets/ILSVRC2016/features_2560/n03379051.mat
# 561 C:/Datasets/ILSVRC2016/features_2560/n03384352.mat
# 562 C:/Datasets/ILSVRC2016/features_2560/n03388043.mat
# 563 C:/Datasets/ILSVRC2016/features_2560/n03388183.mat
# 564 C:/Datasets/ILSVRC2016/features_2560/n03388549.mat
# 565 C:/Datasets/ILSVRC2016/features_2560/n03393912.mat
# 566 C:/Datasets/ILSVRC2016/features_2560/n03394916.mat
# 567 C:/Datasets/ILSVRC2016/features_2560/n03400231.mat
# 568 C:/Datasets/ILSVRC2016/features_2560/n03404251.mat
# 569 C:/Datasets/ILSVRC2016/features_2560/n03417042.mat
# 570 C:/Datasets/ILSVRC2016/features_2560/n03424325.mat
# 571 C:/Datasets/ILSVRC2016/features_2560/n03425413.mat
# 572 C:/Datasets/ILSVRC2016/features_2560/n03443371.mat
# 573 C:/Datasets/ILSVRC2016/features_2560/n03444034.mat
# 574 C:/Datasets/ILSVRC2016/features_2560/n03445777.mat
# 575 C:/Datasets/ILSVRC2016/features_2560/n03445924.mat
# 576 C:/Datasets/ILSVRC2016/features_2560/n03447447.mat
# 577 C:/Datasets/ILSVRC2016/features_2560/n03447721.mat
# 578 C:/Datasets/ILSVRC2016/features_2560/n03450230.mat
# 579 C:/Datasets/ILSVRC2016/features_2560/n03452741.mat
# 580 C:/Datasets/ILSVRC2016/features_2560/n03457902.mat
# 581 C:/Datasets/ILSVRC2016/features_2560/n03459775.mat
# 582 C:/Datasets/ILSVRC2016/features_2560/n03461385.mat
# 583 C:/Datasets/ILSVRC2016/features_2560/n03467068.mat
# 584 C:/Datasets/ILSVRC2016/features_2560/n03476684.mat
# 585 C:/Datasets/ILSVRC2016/features_2560/n03476991.mat
# 586 C:/Datasets/ILSVRC2016/features_2560/n03478589.mat
# 587 C:/Datasets/ILSVRC2016/features_2560/n03481172.mat
# 588 C:/Datasets/ILSVRC2016/features_2560/n03482405.mat
# 589 C:/Datasets/ILSVRC2016/features_2560/n03483316.mat
# 590 C:/Datasets/ILSVRC2016/features_2560/n03485407.mat
# 591 C:/Datasets/ILSVRC2016/features_2560/n03485794.mat
# 592 C:/Datasets/ILSVRC2016/features_2560/n03492542.mat
# 593 C:/Datasets/ILSVRC2016/features_2560/n03494278.mat
# 594 C:/Datasets/ILSVRC2016/features_2560/n03495258.mat
# 595 C:/Datasets/ILSVRC2016/features_2560/n03496892.mat
# 596 C:/Datasets/ILSVRC2016/features_2560/n03498962.mat
# 597 C:/Datasets/ILSVRC2016/features_2560/n03527444.mat
# 598 C:/Datasets/ILSVRC2016/features_2560/n03529860.mat
# 599 C:/Datasets/ILSVRC2016/features_2560/n03530642.mat
# 600 C:/Datasets/ILSVRC2016/features_2560/n03532672.mat
# 601 C:/Datasets/ILSVRC2016/features_2560/n03534580.mat
# 602 C:/Datasets/ILSVRC2016/features_2560/n03535780.mat
# 603 C:/Datasets/ILSVRC2016/features_2560/n03538406.mat
# 604 C:/Datasets/ILSVRC2016/features_2560/n03544143.mat
# 605 C:/Datasets/ILSVRC2016/features_2560/n03584254.mat
# 606 C:/Datasets/ILSVRC2016/features_2560/n03584829.mat
# 607 C:/Datasets/ILSVRC2016/features_2560/n03590841.mat
# 608 C:/Datasets/ILSVRC2016/features_2560/n03594734.mat
# 609 C:/Datasets/ILSVRC2016/features_2560/n03594945.mat
# 610 C:/Datasets/ILSVRC2016/features_2560/n03595614.mat
# 611 C:/Datasets/ILSVRC2016/features_2560/n03598930.mat
# 612 C:/Datasets/ILSVRC2016/features_2560/n03599486.mat
# 613 C:/Datasets/ILSVRC2016/features_2560/n03602883.mat
# 614 C:/Datasets/ILSVRC2016/features_2560/n03617480.mat
# 615 C:/Datasets/ILSVRC2016/features_2560/n03623198.mat
# 616 C:/Datasets/ILSVRC2016/features_2560/n03627232.mat
# 617 C:/Datasets/ILSVRC2016/features_2560/n03630383.mat
# 618 C:/Datasets/ILSVRC2016/features_2560/n03633091.mat
# 619 C:/Datasets/ILSVRC2016/features_2560/n03637318.mat
# 620 C:/Datasets/ILSVRC2016/features_2560/n03642806.mat
# 621 C:/Datasets/ILSVRC2016/features_2560/n03649909.mat
# 622 C:/Datasets/ILSVRC2016/features_2560/n03657121.mat
# 623 C:/Datasets/ILSVRC2016/features_2560/n03658185.mat
# 624 C:/Datasets/ILSVRC2016/features_2560/n03661043.mat
# 625 C:/Datasets/ILSVRC2016/features_2560/n03662601.mat
# 626 C:/Datasets/ILSVRC2016/features_2560/n03666591.mat
# 627 C:/Datasets/ILSVRC2016/features_2560/n03670208.mat
# 628 C:/Datasets/ILSVRC2016/features_2560/n03673027.mat
# 629 C:/Datasets/ILSVRC2016/features_2560/n03676483.mat
# 630 C:/Datasets/ILSVRC2016/features_2560/n03680355.mat
# 631 C:/Datasets/ILSVRC2016/features_2560/n03690938.mat
# 632 C:/Datasets/ILSVRC2016/features_2560/n03691459.mat
# 633 C:/Datasets/ILSVRC2016/features_2560/n03692522.mat
# 634 C:/Datasets/ILSVRC2016/features_2560/n03697007.mat
# 635 C:/Datasets/ILSVRC2016/features_2560/n03706229.mat
# 636 C:/Datasets/ILSVRC2016/features_2560/n03709823.mat
# 637 C:/Datasets/ILSVRC2016/features_2560/n03710193.mat
# 638 C:/Datasets/ILSVRC2016/features_2560/n03710637.mat
# 639 C:/Datasets/ILSVRC2016/features_2560/n03710721.mat
# 640 C:/Datasets/ILSVRC2016/features_2560/n03717622.mat
# 641 C:/Datasets/ILSVRC2016/features_2560/n03720891.mat
# 642 C:/Datasets/ILSVRC2016/features_2560/n03721384.mat
# 643 C:/Datasets/ILSVRC2016/features_2560/n03724870.mat
# 644 C:/Datasets/ILSVRC2016/features_2560/n03729826.mat
# 645 C:/Datasets/ILSVRC2016/features_2560/n03733131.mat
# 646 C:/Datasets/ILSVRC2016/features_2560/n03733281.mat
# 647 C:/Datasets/ILSVRC2016/features_2560/n03733805.mat
# 648 C:/Datasets/ILSVRC2016/features_2560/n03742115.mat
# 649 C:/Datasets/ILSVRC2016/features_2560/n03743016.mat
# 650 C:/Datasets/ILSVRC2016/features_2560/n03759954.mat
# 651 C:/Datasets/ILSVRC2016/features_2560/n03761084.mat
# 652 C:/Datasets/ILSVRC2016/features_2560/n03763968.mat
# 653 C:/Datasets/ILSVRC2016/features_2560/n03764736.mat
# 654 C:/Datasets/ILSVRC2016/features_2560/n03769881.mat
# 655 C:/Datasets/ILSVRC2016/features_2560/n03770439.mat
# 656 C:/Datasets/ILSVRC2016/features_2560/n03770679.mat
# 657 C:/Datasets/ILSVRC2016/features_2560/n03773504.mat
# 658 C:/Datasets/ILSVRC2016/features_2560/n03775071.mat
# 659 C:/Datasets/ILSVRC2016/features_2560/n03775546.mat
# 660 C:/Datasets/ILSVRC2016/features_2560/n03776460.mat
# 661 C:/Datasets/ILSVRC2016/features_2560/n03777568.mat
# 662 C:/Datasets/ILSVRC2016/features_2560/n03777754.mat
# 663 C:/Datasets/ILSVRC2016/features_2560/n03781244.mat
# 664 C:/Datasets/ILSVRC2016/features_2560/n03782006.mat
# 665 C:/Datasets/ILSVRC2016/features_2560/n03785016.mat
# 666 C:/Datasets/ILSVRC2016/features_2560/n03786901.mat
# 667 C:/Datasets/ILSVRC2016/features_2560/n03787032.mat
# 668 C:/Datasets/ILSVRC2016/features_2560/n03788195.mat
# 669 C:/Datasets/ILSVRC2016/features_2560/n03788365.mat
# 670 C:/Datasets/ILSVRC2016/features_2560/n03791053.mat
# 671 C:/Datasets/ILSVRC2016/features_2560/n03792782.mat
# 672 C:/Datasets/ILSVRC2016/features_2560/n03792972.mat
# 673 C:/Datasets/ILSVRC2016/features_2560/n03793489.mat
# 674 C:/Datasets/ILSVRC2016/features_2560/n03794056.mat
# 675 C:/Datasets/ILSVRC2016/features_2560/n03796401.mat
# 676 C:/Datasets/ILSVRC2016/features_2560/n03803284.mat
# 677 C:/Datasets/ILSVRC2016/features_2560/n03804744.mat
# 678 C:/Datasets/ILSVRC2016/features_2560/n03814639.mat
# 679 C:/Datasets/ILSVRC2016/features_2560/n03814906.mat
# 680 C:/Datasets/ILSVRC2016/features_2560/n03825788.mat
# 681 C:/Datasets/ILSVRC2016/features_2560/n03832673.mat
# 682 C:/Datasets/ILSVRC2016/features_2560/n03837869.mat
# 683 C:/Datasets/ILSVRC2016/features_2560/n03838899.mat
# 684 C:/Datasets/ILSVRC2016/features_2560/n03840681.mat
# 685 C:/Datasets/ILSVRC2016/features_2560/n03841143.mat
# 686 C:/Datasets/ILSVRC2016/features_2560/n03843555.mat
# 687 C:/Datasets/ILSVRC2016/features_2560/n03854065.mat
# 688 C:/Datasets/ILSVRC2016/features_2560/n03857828.mat
# 689 C:/Datasets/ILSVRC2016/features_2560/n03866082.mat
# 690 C:/Datasets/ILSVRC2016/features_2560/n03868242.mat
# 691 C:/Datasets/ILSVRC2016/features_2560/n03868863.mat
# 692 C:/Datasets/ILSVRC2016/features_2560/n03871628.mat
# 693 C:/Datasets/ILSVRC2016/features_2560/n03873416.mat
# 694 C:/Datasets/ILSVRC2016/features_2560/n03874293.mat
# 695 C:/Datasets/ILSVRC2016/features_2560/n03874599.mat
# 696 C:/Datasets/ILSVRC2016/features_2560/n03876231.mat
# 697 C:/Datasets/ILSVRC2016/features_2560/n03877472.mat
# 698 C:/Datasets/ILSVRC2016/features_2560/n03877845.mat
# 699 C:/Datasets/ILSVRC2016/features_2560/n03884397.mat
# 700 C:/Datasets/ILSVRC2016/features_2560/n03887697.mat
# 701 C:/Datasets/ILSVRC2016/features_2560/n03888257.mat
# 702 C:/Datasets/ILSVRC2016/features_2560/n03888605.mat
# 703 C:/Datasets/ILSVRC2016/features_2560/n03891251.mat
# 704 C:/Datasets/ILSVRC2016/features_2560/n03891332.mat
# 705 C:/Datasets/ILSVRC2016/features_2560/n03895866.mat
# 706 C:/Datasets/ILSVRC2016/features_2560/n03899768.mat
# 707 C:/Datasets/ILSVRC2016/features_2560/n03902125.mat
# 708 C:/Datasets/ILSVRC2016/features_2560/n03903868.mat
# 709 C:/Datasets/ILSVRC2016/features_2560/n03908618.mat
# 710 C:/Datasets/ILSVRC2016/features_2560/n03908714.mat
# 711 C:/Datasets/ILSVRC2016/features_2560/n03916031.mat
# 712 C:/Datasets/ILSVRC2016/features_2560/n03920288.mat
# 713 C:/Datasets/ILSVRC2016/features_2560/n03924679.mat
# 714 C:/Datasets/ILSVRC2016/features_2560/n03929660.mat
# 715 C:/Datasets/ILSVRC2016/features_2560/n03929855.mat
# 716 C:/Datasets/ILSVRC2016/features_2560/n03930313.mat
# 717 C:/Datasets/ILSVRC2016/features_2560/n03930630.mat
# 718 C:/Datasets/ILSVRC2016/features_2560/n03933933.mat
# 719 C:/Datasets/ILSVRC2016/features_2560/n03935335.mat
# 720 C:/Datasets/ILSVRC2016/features_2560/n03937543.mat
# 721 C:/Datasets/ILSVRC2016/features_2560/n03938244.mat
# 722 C:/Datasets/ILSVRC2016/features_2560/n03942813.mat
# 723 C:/Datasets/ILSVRC2016/features_2560/n03944341.mat
# 724 C:/Datasets/ILSVRC2016/features_2560/n03947888.mat
# 725 C:/Datasets/ILSVRC2016/features_2560/n03950228.mat
# 726 C:/Datasets/ILSVRC2016/features_2560/n03954731.mat
# 727 C:/Datasets/ILSVRC2016/features_2560/n03956157.mat
# 728 C:/Datasets/ILSVRC2016/features_2560/n03958227.mat
# 729 C:/Datasets/ILSVRC2016/features_2560/n03961711.mat
# 730 C:/Datasets/ILSVRC2016/features_2560/n03967562.mat
# 731 C:/Datasets/ILSVRC2016/features_2560/n03970156.mat
# 732 C:/Datasets/ILSVRC2016/features_2560/n03976467.mat
# 733 C:/Datasets/ILSVRC2016/features_2560/n03976657.mat
# 734 C:/Datasets/ILSVRC2016/features_2560/n03977966.mat
# 735 C:/Datasets/ILSVRC2016/features_2560/n03980874.mat
# 736 C:/Datasets/ILSVRC2016/features_2560/n03982430.mat
# 737 C:/Datasets/ILSVRC2016/features_2560/n03983396.mat
# 738 C:/Datasets/ILSVRC2016/features_2560/n03991062.mat
# 739 C:/Datasets/ILSVRC2016/features_2560/n03992509.mat
# 740 C:/Datasets/ILSVRC2016/features_2560/n03995372.mat
# 741 C:/Datasets/ILSVRC2016/features_2560/n03998194.mat
# 742 C:/Datasets/ILSVRC2016/features_2560/n04004767.mat
# 743 C:/Datasets/ILSVRC2016/features_2560/n04005630.mat
# 744 C:/Datasets/ILSVRC2016/features_2560/n04008634.mat
# 745 C:/Datasets/ILSVRC2016/features_2560/n04009552.mat
# 746 C:/Datasets/ILSVRC2016/features_2560/n04019541.mat
# 747 C:/Datasets/ILSVRC2016/features_2560/n04023962.mat
# 748 C:/Datasets/ILSVRC2016/features_2560/n04026417.mat
# 749 C:/Datasets/ILSVRC2016/features_2560/n04033901.mat
# 750 C:/Datasets/ILSVRC2016/features_2560/n04033995.mat
# 751 C:/Datasets/ILSVRC2016/features_2560/n04037443.mat
# 752 C:/Datasets/ILSVRC2016/features_2560/n04039381.mat
# 753 C:/Datasets/ILSVRC2016/features_2560/n04040759.mat
# 754 C:/Datasets/ILSVRC2016/features_2560/n04041544.mat
# 755 C:/Datasets/ILSVRC2016/features_2560/n04044716.mat
# 756 C:/Datasets/ILSVRC2016/features_2560/n04049303.mat
# 757 C:/Datasets/ILSVRC2016/features_2560/n04065272.mat
# 758 C:/Datasets/ILSVRC2016/features_2560/n04067472.mat
# 759 C:/Datasets/ILSVRC2016/features_2560/n04069434.mat
# 760 C:/Datasets/ILSVRC2016/features_2560/n04070727.mat
# 761 C:/Datasets/ILSVRC2016/features_2560/n04074963.mat
# 762 C:/Datasets/ILSVRC2016/features_2560/n04081281.mat
# 763 C:/Datasets/ILSVRC2016/features_2560/n04086273.mat
# 764 C:/Datasets/ILSVRC2016/features_2560/n04090263.mat
# 765 C:/Datasets/ILSVRC2016/features_2560/n04099969.mat
# 766 C:/Datasets/ILSVRC2016/features_2560/n04111531.mat
# 767 C:/Datasets/ILSVRC2016/features_2560/n04116512.mat
# 768 C:/Datasets/ILSVRC2016/features_2560/n04118538.mat
# 769 C:/Datasets/ILSVRC2016/features_2560/n04118776.mat
# 770 C:/Datasets/ILSVRC2016/features_2560/n04120489.mat
# 771 C:/Datasets/ILSVRC2016/features_2560/n04125021.mat
# 772 C:/Datasets/ILSVRC2016/features_2560/n04127249.mat
# 773 C:/Datasets/ILSVRC2016/features_2560/n04131690.mat
# 774 C:/Datasets/ILSVRC2016/features_2560/n04133789.mat
# 775 C:/Datasets/ILSVRC2016/features_2560/n04136333.mat
# 776 C:/Datasets/ILSVRC2016/features_2560/n04141076.mat
# 777 C:/Datasets/ILSVRC2016/features_2560/n04141327.mat
# 778 C:/Datasets/ILSVRC2016/features_2560/n04141975.mat
# 779 C:/Datasets/ILSVRC2016/features_2560/n04146614.mat
# 780 C:/Datasets/ILSVRC2016/features_2560/n04147183.mat
# 781 C:/Datasets/ILSVRC2016/features_2560/n04149813.mat
# 782 C:/Datasets/ILSVRC2016/features_2560/n04152593.mat
# 783 C:/Datasets/ILSVRC2016/features_2560/n04153751.mat
# 784 C:/Datasets/ILSVRC2016/features_2560/n04154565.mat
# 785 C:/Datasets/ILSVRC2016/features_2560/n04162706.mat
# 786 C:/Datasets/ILSVRC2016/features_2560/n04179913.mat
# 787 C:/Datasets/ILSVRC2016/features_2560/n04192698.mat
# 788 C:/Datasets/ILSVRC2016/features_2560/n04200800.mat
# 789 C:/Datasets/ILSVRC2016/features_2560/n04201297.mat
# 790 C:/Datasets/ILSVRC2016/features_2560/n04204238.mat
# 791 C:/Datasets/ILSVRC2016/features_2560/n04204347.mat
# 792 C:/Datasets/ILSVRC2016/features_2560/n04208210.mat
# 793 C:/Datasets/ILSVRC2016/features_2560/n04209133.mat
# 794 C:/Datasets/ILSVRC2016/features_2560/n04209239.mat
# 795 C:/Datasets/ILSVRC2016/features_2560/n04228054.mat
# 796 C:/Datasets/ILSVRC2016/features_2560/n04229816.mat
# 797 C:/Datasets/ILSVRC2016/features_2560/n04235860.mat
# 798 C:/Datasets/ILSVRC2016/features_2560/n04238763.mat
# 799 C:/Datasets/ILSVRC2016/features_2560/n04239074.mat
# 800 C:/Datasets/ILSVRC2016/features_2560/n04243546.mat
# 801 C:/Datasets/ILSVRC2016/features_2560/n04251144.mat
# 802 C:/Datasets/ILSVRC2016/features_2560/n04252077.mat
# 803 C:/Datasets/ILSVRC2016/features_2560/n04252225.mat
# 804 C:/Datasets/ILSVRC2016/features_2560/n04254120.mat
# 805 C:/Datasets/ILSVRC2016/features_2560/n04254680.mat
# 806 C:/Datasets/ILSVRC2016/features_2560/n04254777.mat
# 807 C:/Datasets/ILSVRC2016/features_2560/n04258138.mat
# 808 C:/Datasets/ILSVRC2016/features_2560/n04259630.mat
# 809 C:/Datasets/ILSVRC2016/features_2560/n04263257.mat
# 810 C:/Datasets/ILSVRC2016/features_2560/n04264628.mat
# 811 C:/Datasets/ILSVRC2016/features_2560/n04265275.mat
# 812 C:/Datasets/ILSVRC2016/features_2560/n04266014.mat
# 813 C:/Datasets/ILSVRC2016/features_2560/n04270147.mat
# 814 C:/Datasets/ILSVRC2016/features_2560/n04273569.mat
# 815 C:/Datasets/ILSVRC2016/features_2560/n04275548.mat
# 816 C:/Datasets/ILSVRC2016/features_2560/n04277352.mat
# 817 C:/Datasets/ILSVRC2016/features_2560/n04285008.mat
# 818 C:/Datasets/ILSVRC2016/features_2560/n04286575.mat
# 819 C:/Datasets/ILSVRC2016/features_2560/n04296562.mat
# 820 C:/Datasets/ILSVRC2016/features_2560/n04310018.mat
# 821 C:/Datasets/ILSVRC2016/features_2560/n04311004.mat
# 822 C:/Datasets/ILSVRC2016/features_2560/n04311174.mat
# 823 C:/Datasets/ILSVRC2016/features_2560/n04317175.mat
# 824 C:/Datasets/ILSVRC2016/features_2560/n04325704.mat
# 825 C:/Datasets/ILSVRC2016/features_2560/n04326547.mat
# 826 C:/Datasets/ILSVRC2016/features_2560/n04328186.mat
# 827 C:/Datasets/ILSVRC2016/features_2560/n04330267.mat
# 828 C:/Datasets/ILSVRC2016/features_2560/n04332243.mat
# 829 C:/Datasets/ILSVRC2016/features_2560/n04335435.mat
# 830 C:/Datasets/ILSVRC2016/features_2560/n04336792.mat
# 831 C:/Datasets/ILSVRC2016/features_2560/n04344873.mat
# 832 C:/Datasets/ILSVRC2016/features_2560/n04346328.mat
# 833 C:/Datasets/ILSVRC2016/features_2560/n04347754.mat
# 834 C:/Datasets/ILSVRC2016/features_2560/n04350905.mat
# 835 C:/Datasets/ILSVRC2016/features_2560/n04355338.mat
# 836 C:/Datasets/ILSVRC2016/features_2560/n04355933.mat
# 837 C:/Datasets/ILSVRC2016/features_2560/n04356056.mat
# 838 C:/Datasets/ILSVRC2016/features_2560/n04357314.mat
# 839 C:/Datasets/ILSVRC2016/features_2560/n04366367.mat
# 840 C:/Datasets/ILSVRC2016/features_2560/n04367480.mat
# 841 C:/Datasets/ILSVRC2016/features_2560/n04370456.mat
# 842 C:/Datasets/ILSVRC2016/features_2560/n04371430.mat
# 843 C:/Datasets/ILSVRC2016/features_2560/n04371774.mat
# 844 C:/Datasets/ILSVRC2016/features_2560/n04372370.mat
# 845 C:/Datasets/ILSVRC2016/features_2560/n04376876.mat
# 846 C:/Datasets/ILSVRC2016/features_2560/n04380533.mat
# 847 C:/Datasets/ILSVRC2016/features_2560/n04389033.mat
# 848 C:/Datasets/ILSVRC2016/features_2560/n04392985.mat
# 849 C:/Datasets/ILSVRC2016/features_2560/n04398044.mat
# 850 C:/Datasets/ILSVRC2016/features_2560/n04399382.mat
# 851 C:/Datasets/ILSVRC2016/features_2560/n04404412.mat
# 852 C:/Datasets/ILSVRC2016/features_2560/n04409515.mat
# 853 C:/Datasets/ILSVRC2016/features_2560/n04417672.mat
# 854 C:/Datasets/ILSVRC2016/features_2560/n04418357.mat
# 855 C:/Datasets/ILSVRC2016/features_2560/n04423845.mat
# 856 C:/Datasets/ILSVRC2016/features_2560/n04428191.mat
# 857 C:/Datasets/ILSVRC2016/features_2560/n04429376.mat
# 858 C:/Datasets/ILSVRC2016/features_2560/n04435653.mat
# 859 C:/Datasets/ILSVRC2016/features_2560/n04442312.mat
# 860 C:/Datasets/ILSVRC2016/features_2560/n04443257.mat
# 861 C:/Datasets/ILSVRC2016/features_2560/n04447861.mat
# 862 C:/Datasets/ILSVRC2016/features_2560/n04456115.mat
# 863 C:/Datasets/ILSVRC2016/features_2560/n04458633.mat
# 864 C:/Datasets/ILSVRC2016/features_2560/n04461696.mat
# 865 C:/Datasets/ILSVRC2016/features_2560/n04462240.mat
# 866 C:/Datasets/ILSVRC2016/features_2560/n04465501.mat
# 867 C:/Datasets/ILSVRC2016/features_2560/n04467665.mat
# 868 C:/Datasets/ILSVRC2016/features_2560/n04476259.mat
# 869 C:/Datasets/ILSVRC2016/features_2560/n04479046.mat
# 870 C:/Datasets/ILSVRC2016/features_2560/n04482393.mat
# 871 C:/Datasets/ILSVRC2016/features_2560/n04483307.mat
# 872 C:/Datasets/ILSVRC2016/features_2560/n04485082.mat
# 873 C:/Datasets/ILSVRC2016/features_2560/n04486054.mat
# 874 C:/Datasets/ILSVRC2016/features_2560/n04487081.mat
# 875 C:/Datasets/ILSVRC2016/features_2560/n04487394.mat
# 876 C:/Datasets/ILSVRC2016/features_2560/n04493381.mat
# 877 C:/Datasets/ILSVRC2016/features_2560/n04501370.mat
# 878 C:/Datasets/ILSVRC2016/features_2560/n04505470.mat
# 879 C:/Datasets/ILSVRC2016/features_2560/n04507155.mat
# 880 C:/Datasets/ILSVRC2016/features_2560/n04509417.mat
# 881 C:/Datasets/ILSVRC2016/features_2560/n04515003.mat
# 882 C:/Datasets/ILSVRC2016/features_2560/n04517823.mat
# 883 C:/Datasets/ILSVRC2016/features_2560/n04522168.mat
# 884 C:/Datasets/ILSVRC2016/features_2560/n04523525.mat
# 885 C:/Datasets/ILSVRC2016/features_2560/n04525038.mat
# 886 C:/Datasets/ILSVRC2016/features_2560/n04525305.mat
# 887 C:/Datasets/ILSVRC2016/features_2560/n04532106.mat
# 888 C:/Datasets/ILSVRC2016/features_2560/n04532670.mat
# 889 C:/Datasets/ILSVRC2016/features_2560/n04536866.mat
# 890 C:/Datasets/ILSVRC2016/features_2560/n04540053.mat
# 891 C:/Datasets/ILSVRC2016/features_2560/n04542943.mat
# 892 C:/Datasets/ILSVRC2016/features_2560/n04548280.mat
# 893 C:/Datasets/ILSVRC2016/features_2560/n04548362.mat
# 894 C:/Datasets/ILSVRC2016/features_2560/n04550184.mat
# 895 C:/Datasets/ILSVRC2016/features_2560/n04552348.mat
# 896 C:/Datasets/ILSVRC2016/features_2560/n04553703.mat
# 897 C:/Datasets/ILSVRC2016/features_2560/n04554684.mat
# 898 C:/Datasets/ILSVRC2016/features_2560/n04557648.mat
# 899 C:/Datasets/ILSVRC2016/features_2560/n04560804.mat
# 900 C:/Datasets/ILSVRC2016/features_2560/n04562935.mat
# 901 C:/Datasets/ILSVRC2016/features_2560/n04579145.mat
# 902 C:/Datasets/ILSVRC2016/features_2560/n04579432.mat
# 903 C:/Datasets/ILSVRC2016/features_2560/n04584207.mat
# 904 C:/Datasets/ILSVRC2016/features_2560/n04589890.mat
# 905 C:/Datasets/ILSVRC2016/features_2560/n04590129.mat
# 906 C:/Datasets/ILSVRC2016/features_2560/n04591157.mat
# 907 C:/Datasets/ILSVRC2016/features_2560/n04591713.mat
# 908 C:/Datasets/ILSVRC2016/features_2560/n04592741.mat
# 909 C:/Datasets/ILSVRC2016/features_2560/n04596742.mat
# 910 C:/Datasets/ILSVRC2016/features_2560/n04597913.mat
# 911 C:/Datasets/ILSVRC2016/features_2560/n04599235.mat
# 912 C:/Datasets/ILSVRC2016/features_2560/n04604644.mat
# 913 C:/Datasets/ILSVRC2016/features_2560/n04606251.mat
# 914 C:/Datasets/ILSVRC2016/features_2560/n04612504.mat
# 915 C:/Datasets/ILSVRC2016/features_2560/n04613696.mat
# 916 C:/Datasets/ILSVRC2016/features_2560/n06359193.mat
# 917 C:/Datasets/ILSVRC2016/features_2560/n06596364.mat
# 918 C:/Datasets/ILSVRC2016/features_2560/n06785654.mat
# 919 C:/Datasets/ILSVRC2016/features_2560/n06794110.mat
# 920 C:/Datasets/ILSVRC2016/features_2560/n06874185.mat
# 921 C:/Datasets/ILSVRC2016/features_2560/n07248320.mat
# 922 C:/Datasets/ILSVRC2016/features_2560/n07565083.mat
# 923 C:/Datasets/ILSVRC2016/features_2560/n07579787.mat
# 924 C:/Datasets/ILSVRC2016/features_2560/n07583066.mat
# 925 C:/Datasets/ILSVRC2016/features_2560/n07584110.mat
# 926 C:/Datasets/ILSVRC2016/features_2560/n07590611.mat
# 927 C:/Datasets/ILSVRC2016/features_2560/n07613480.mat
# 928 C:/Datasets/ILSVRC2016/features_2560/n07614500.mat
# 929 C:/Datasets/ILSVRC2016/features_2560/n07615774.mat
# 930 C:/Datasets/ILSVRC2016/features_2560/n07684084.mat
# 931 C:/Datasets/ILSVRC2016/features_2560/n07693725.mat
# 932 C:/Datasets/ILSVRC2016/features_2560/n07695742.mat
# 933 C:/Datasets/ILSVRC2016/features_2560/n07697313.mat
# 934 C:/Datasets/ILSVRC2016/features_2560/n07697537.mat
# 935 C:/Datasets/ILSVRC2016/features_2560/n07711569.mat
# 936 C:/Datasets/ILSVRC2016/features_2560/n07714571.mat
# 937 C:/Datasets/ILSVRC2016/features_2560/n07714990.mat
# 938 C:/Datasets/ILSVRC2016/features_2560/n07715103.mat
# 939 C:/Datasets/ILSVRC2016/features_2560/n07716358.mat
# 940 C:/Datasets/ILSVRC2016/features_2560/n07716906.mat
# 941 C:/Datasets/ILSVRC2016/features_2560/n07717410.mat
# 942 C:/Datasets/ILSVRC2016/features_2560/n07717556.mat
# 943 C:/Datasets/ILSVRC2016/features_2560/n07718472.mat
# 944 C:/Datasets/ILSVRC2016/features_2560/n07718747.mat
# 945 C:/Datasets/ILSVRC2016/features_2560/n07720875.mat
# 946 C:/Datasets/ILSVRC2016/features_2560/n07730033.mat
# 947 C:/Datasets/ILSVRC2016/features_2560/n07734744.mat
# 948 C:/Datasets/ILSVRC2016/features_2560/n07742313.mat
# 949 C:/Datasets/ILSVRC2016/features_2560/n07745940.mat
# 950 C:/Datasets/ILSVRC2016/features_2560/n07747607.mat
# 951 C:/Datasets/ILSVRC2016/features_2560/n07749582.mat
# 952 C:/Datasets/ILSVRC2016/features_2560/n07753113.mat
# 953 C:/Datasets/ILSVRC2016/features_2560/n07753275.mat
# 954 C:/Datasets/ILSVRC2016/features_2560/n07753592.mat
# 955 C:/Datasets/ILSVRC2016/features_2560/n07754684.mat
# 956 C:/Datasets/ILSVRC2016/features_2560/n07760859.mat
# 957 C:/Datasets/ILSVRC2016/features_2560/n07768694.mat
# 958 C:/Datasets/ILSVRC2016/features_2560/n07802026.mat
# 959 C:/Datasets/ILSVRC2016/features_2560/n07831146.mat
# 960 C:/Datasets/ILSVRC2016/features_2560/n07836838.mat
# 961 C:/Datasets/ILSVRC2016/features_2560/n07860988.mat
# 962 C:/Datasets/ILSVRC2016/features_2560/n07871810.mat
# 963 C:/Datasets/ILSVRC2016/features_2560/n07873807.mat
# 964 C:/Datasets/ILSVRC2016/features_2560/n07875152.mat
# 965 C:/Datasets/ILSVRC2016/features_2560/n07880968.mat
# 966 C:/Datasets/ILSVRC2016/features_2560/n07892512.mat
# 967 C:/Datasets/ILSVRC2016/features_2560/n07920052.mat
# 968 C:/Datasets/ILSVRC2016/features_2560/n07930864.mat
# 969 C:/Datasets/ILSVRC2016/features_2560/n07932039.mat
# 970 C:/Datasets/ILSVRC2016/features_2560/n09193705.mat
# 971 C:/Datasets/ILSVRC2016/features_2560/n09229709.mat
# 972 C:/Datasets/ILSVRC2016/features_2560/n09246464.mat
# 973 C:/Datasets/ILSVRC2016/features_2560/n09256479.mat
# 974 C:/Datasets/ILSVRC2016/features_2560/n09288635.mat
# 975 C:/Datasets/ILSVRC2016/features_2560/n09332890.mat
# 976 C:/Datasets/ILSVRC2016/features_2560/n09399592.mat
# 977 C:/Datasets/ILSVRC2016/features_2560/n09421951.mat
# 978 C:/Datasets/ILSVRC2016/features_2560/n09428293.mat
# 979 C:/Datasets/ILSVRC2016/features_2560/n09468604.mat
# 980 C:/Datasets/ILSVRC2016/features_2560/n09472597.mat
# 981 C:/Datasets/ILSVRC2016/features_2560/n09835506.mat
# 982 C:/Datasets/ILSVRC2016/features_2560/n10148035.mat
# 983 C:/Datasets/ILSVRC2016/features_2560/n10565667.mat
# 984 C:/Datasets/ILSVRC2016/features_2560/n11879895.mat
# 985 C:/Datasets/ILSVRC2016/features_2560/n11939491.mat
# 986 C:/Datasets/ILSVRC2016/features_2560/n12057211.mat
# 987 C:/Datasets/ILSVRC2016/features_2560/n12144580.mat
# 988 C:/Datasets/ILSVRC2016/features_2560/n12267677.mat
# 989 C:/Datasets/ILSVRC2016/features_2560/n12620546.mat
# 990 C:/Datasets/ILSVRC2016/features_2560/n12768682.mat
# 991 C:/Datasets/ILSVRC2016/features_2560/n12985857.mat
# 992 C:/Datasets/ILSVRC2016/features_2560/n12998815.mat
# 993 C:/Datasets/ILSVRC2016/features_2560/n13037406.mat
# 994 C:/Datasets/ILSVRC2016/features_2560/n13040303.mat
# 995 C:/Datasets/ILSVRC2016/features_2560/n13044778.mat
# 996 C:/Datasets/ILSVRC2016/features_2560/n13052670.mat
# 997 C:/Datasets/ILSVRC2016/features_2560/n13054560.mat
# 998 C:/Datasets/ILSVRC2016/features_2560/n13133613.mat
# 999 C:/Datasets/ILSVRC2016/features_2560/n15075141.mat

# %%
from os import listdir
from os.path import isfile, join
import xml.etree.ElementTree as ET
def ParseAnoXml(path):
    files = [f for f in listdir(path) if isfile(join(path, f))]
    classes={}
    nf=len(files)
    for i in range(nf):
        f=files[i]
        tree = ET.parse(path+f)
        root = tree.getroot()
        child=root.findall("./object/name")[0]
        fj=f[0:-4]+'.jpeg'
        if child.text in classes.keys():
            classes[child.text].append(fj)
        else:
            classes[child.text]=[fj]
        if i%1000==0:
            print(i,fj)
    return classes
path='d:/Datasets/ILSVRC2016/ILSVRC/Annotations/CLS-LOC/val/'
classes=ParseAnoXml(path)
torch.save(classes,'classes_val.pth')
print('done')
# Out:
# 0 ILSVRC2012_val_00000001.jpeg
# 1000 ILSVRC2012_val_00001001.jpeg
# 2000 ILSVRC2012_val_00002001.jpeg
# 3000 ILSVRC2012_val_00003001.jpeg
# 4000 ILSVRC2012_val_00004001.jpeg
# 5000 ILSVRC2012_val_00005001.jpeg
# 6000 ILSVRC2012_val_00006001.jpeg
# 7000 ILSVRC2012_val_00007001.jpeg
# 8000 ILSVRC2012_val_00008001.jpeg
# 9000 ILSVRC2012_val_00009001.jpeg
# 10000 ILSVRC2012_val_00010001.jpeg
# 11000 ILSVRC2012_val_00011001.jpeg
# 12000 ILSVRC2012_val_00012001.jpeg
# 13000 ILSVRC2012_val_00013001.jpeg
# 14000 ILSVRC2012_val_00014001.jpeg
# 15000 ILSVRC2012_val_00015001.jpeg
# 16000 ILSVRC2012_val_00016001.jpeg
# 17000 ILSVRC2012_val_00017001.jpeg
# 18000 ILSVRC2012_val_00018001.jpeg
# 19000 ILSVRC2012_val_00019001.jpeg
# 20000 ILSVRC2012_val_00020001.jpeg
# 21000 ILSVRC2012_val_00021001.jpeg
# 22000 ILSVRC2012_val_00022001.jpeg
# 23000 ILSVRC2012_val_00023001.jpeg
# 24000 ILSVRC2012_val_00024001.jpeg
# 25000 ILSVRC2012_val_00025001.jpeg
# 26000 ILSVRC2012_val_00026001.jpeg
# 27000 ILSVRC2012_val_00027001.jpeg
# 28000 ILSVRC2012_val_00028001.jpeg
# 29000 ILSVRC2012_val_00029001.jpeg
# 30000 ILSVRC2012_val_00030001.jpeg
# 31000 ILSVRC2012_val_00031001.jpeg
# 32000 ILSVRC2012_val_00032001.jpeg
# 33000 ILSVRC2012_val_00033001.jpeg
# 34000 ILSVRC2012_val_00034001.jpeg
# 35000 ILSVRC2012_val_00035001.jpeg
# 36000 ILSVRC2012_val_00036001.jpeg
# 37000 ILSVRC2012_val_00037001.jpeg
# 38000 ILSVRC2012_val_00038001.jpeg
# 39000 ILSVRC2012_val_00039001.jpeg
# 40000 ILSVRC2012_val_00040001.jpeg
# 41000 ILSVRC2012_val_00041001.jpeg
# 42000 ILSVRC2012_val_00042001.jpeg
# 43000 ILSVRC2012_val_00043001.jpeg
# 44000 ILSVRC2012_val_00044001.jpeg
# 45000 ILSVRC2012_val_00045001.jpeg
# 46000 ILSVRC2012_val_00046001.jpeg
# 47000 ILSVRC2012_val_00047001.jpeg
# 48000 ILSVRC2012_val_00048001.jpeg
# 49000 ILSVRC2012_val_00049001.jpeg
# done

# %%
from os import listdir
from os.path import isfile, join
from PIL import Image
from torch.utils.data import Dataset,TensorDataset, DataLoader
def ComputeFeatures(path,files,nx): 
    n=len(files)
    x=torch.zeros([n,3,nx,nx], dtype=torch.float32)
    for i in range(n):
        im = Image.open(join(path, files[i]))
        x[i,:,:,:]=_transform(nx)(im)
    data=TensorDataset(x)
    loader=DataLoader(data,batch_size=256,shuffle=False)
    i=0
    for images in loader:
        images=images[0].to(device)
        with torch.no_grad():
            fi=features(model.visual,images)    
        if i==0:
            X=fi
        else:
            X=torch.cat((X,fi),dim=0)
        i+=1
    return X.squeeze().float()
# save test features
nx=288
print(nx)
for i in range(nc):
    path='C:/Datasets/ILSVRC2016/ILSVRC/Data/CLS-LOC/val/'
    files=classes[names[i]]
    x=ComputeFeatures(path,files,nx)
    name='C:/Datasets/ILSVRC2016/features_val_640/'+names[i]+'.mat'
    if i%100==0:
        print(i)
    savemat(name,{'feature':x.cpu().float().numpy()})
# Out:
# 288
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900

# %%
# compute features and train PCAs
# save model for each class separately
from os import listdir
from os.path import isfile, join
from PIL import Image
from torch.utils.data import Dataset,TensorDataset, DataLoader

def ComputeFeatures(path,files,nx): 
    n=len(files)
    x=torch.zeros([n,3,nx,nx], dtype=torch.float32)
    for i in range(n):
        im = Image.open(join(path, files[i]))
        x[i,:,:,:]=_transform(nx)(im)
    data=TensorDataset(x)
    loader=DataLoader(data,batch_size=256,shuffle=False)
    i=0
    for images in loader:
        images=images[0].to(device)
        with torch.no_grad():
            fi=features(model.visual,images)    
        if i==0:
            X=fi
        else:
            X=torch.cat((X,fi),dim=0)
        i+=1
    return X.squeeze().float()

nx=288
nc=1000
k=400  # number of Pcs
N=0.1
la=N**2
for i in range(nc):
    #x=load_data(names[i])
    path='C:/Datasets/ILSVRC2016/ILSVRC/Data/CLS-LOC/train/'+names[i]
    files = [f for f in listdir(path) if isfile(join(path, f))]
    x=ComputeFeatures(path,files,nx)
    mx=torch.mean(x,dim=0)
    u,s,v = torch.linalg.svd(x-mx)
    L=v[0:k,:]
    S=s[0:k]
    name='C:/Datasets/ILSVRC2016/Model/'+names[i]+'.pth'
    torch.save({'mx':mx,'L':L, 'S':S},name)    
    if i%50==0:
        print(i)
print('done')

# %%
# train PCAs
nc=len(names)
k=100  # number of Pcs
N=0.1
la=N**2
path='c:/datasets/ImageNet/features_640/'
n=0
for i in range(nc):
    x=load_data(path,names[i])
    n+=x.shape[0]
    if (i%1000==999):
        print(n)
    continue
    #x=X[y==i,:].to(device)
    if i==0:
        d=x.shape[1]
        e=torch.eye(d,device=device)
        mx=torch.zeros((nc,d),device=device)
        L=torch.zeros((nc,k,d),device=device)
        S=torch.zeros((nc,k),device=device)
    mx[i,:]=torch.mean(x,dim=0)
    u,s,v = torch.linalg.svd(x-mx[i,:])
    L[i,:,:]=v[0:k,:]
    S[i,:]=s[0:k]
    if i%100==0:
        print(i)
print('done')
print(n)
#torch.save({'mx':mx,'L':L, 'S':S},'c:/tmp/pca_Imagenet.pth')
# Out:
# 1082869
# 2204762
# 3294682
# 4383413
# 5468356
# 6543512
# 7639423
# 8639651
# 9677249
# 10634326
# done
# 11060192

# %%
# train PCAs
# save model separately for each class
nc=len(names)
k=400  # number of Pcs
N=0.1
la=N**2
path='c:/datasets/ILSVRC2016/features_640/'
for i in range(nc):
    x=load_data(path,names[i])
    #x=X[y==i,:].to(device)
    mx=torch.mean(x,dim=0)
    u,s,v = torch.linalg.svd(x-mx)
    L=v[0:k,:]
    S=s[0:k]
    name='C:/Datasets/Imagenet/Model/'+names[i]+'.pth'
    torch.save({'mx':mx,'L':L, 'S':S},name)    
    if i%500==0:
        print(i)
print('done')

# %%
# load the models from a single file
m=torch.load('pca640_288_Imagenet.pth')
#m=torch.load('d:/tmp/pca640_Imagenet.pth')
mx=m['mx']
print(m['L'].shape)
k=20
L=m['L'][:,0:k,:]
S=m['S'][:,0:k]
#torch.save({'mx':mx,'L':L, 'S':S},'pca640_288_Imagenet.pth')
# Out:
# torch.Size([1000, 20, 640])

# %%
torch.save({'mx':mx,'L':L.cpu().to(device), 'S':S.cpu().to(device)},'pca640_288_Imagenet.pth')

# %%
# load the models saved separately
nc=len(names)
k=100  # number of Pcs
for i in range(nc):
    name='C:/Datasets/Imagenet/Model/'+names[i]+'.pth'
    m=torch.load(name)
    Li=m['L']
    if i==0:
        mx=torch.zeros((nc,Li.shape[1]),dtype=torch.float32)
        L=torch.zeros((nc,k,Li.shape[1]),dtype=torch.float32)
        S=torch.zeros((nc,k),dtype=torch.float32)
    mx[i,:]=m['mx'].float().cpu()
    L[i,:,:]=m['L'][0:k,:].float().cpu()
    S[i,:]=m['S'][0:k].cpu()
    if i%1000==0:
        print(i)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000

# %%
la=0.01
i=0
py=classify(X,mx.cpu(),L.cpu(),S.cpu(),la)
print('done')
confmat=confusion_matrix(y.cpu().numpy(),py.cpu().numpy())
print(100-np.sum(np.diag(confmat))/np.sum(confmat)*100)
cv2.imwrite('c:/tmp/conf.png',confmat)
# Out:
# done
# 70.68
# True

# %%
k=10
L=L[:,0:k,:]
S=S[:,0:k]

# %%
si=compute_sigma(L[0,:,:],S[0,:],0.01)
ld=(640-k)*np.log(0.01)+torch.sum(torch.log(S[0,:]**2+0.01))
print(ld,torch.logdet(si))
# Out:
# tensor(-2767.4937, device='cuda:0') tensor(-2767.4941, device='cuda:0')

# %%
from scipy.optimize import linear_sum_assignment
from sklearn.metrics import confusion_matrix
#import cv2


def load_datat(i):
    #name='c:/datasets/ILSVRC2016/Features_val_640/%d.mat'%(i+1)
    name='d:/datasets/ILSVRC2016/features_val_640/'+names[i]
    #name='d:/datasets/Imagenet/features_val_640/'+names[i]
    m=loadmat(name)
    x=torch.tensor(m['feature']).float().to(device)
    return x

def response(x1,mu,L,S,la):
    # response using L,S (fast), using the math computation above
    # xSigma^-1 x = x^Tx/lambda - u^Tu/lambda where u = S/(S^2+lambda)^0.5Lx
    x=x1-mu
    Lx=x@L.t()
    Qx=(S/torch.sqrt(S**2+la)).unsqueeze(0)*Lx
    return (torch.sum(x**2,dim=1)-torch.sum(Qx**2,dim=1))/la

def response1(x1,mu):
    # response using L,S (fast), using the math computation above
    # xSigma^-1 x = x^Tx/lambda - u^Tu/lambda where u = S/(S^2+lambda)^0.5Lx
    x=x1-mu
    return torch.sum(x**2,dim=1)

def compute_sigma(L,S,la):
    e=torch.eye(L.shape[1],device=L.device)
    s2L=(S**2).unsqueeze(1)*L #W=SL
    si = L.t()@s2L
    si+= e*la #Sigma=L^TS^2L+lambda I
    return si

def compute_si(x):
    u,s,v = torch.linalg.svd(x)
    L=v[0:k,:]
    S=s[0:k]
    s2L=(S**2).unsqueeze(1)*L #W=SL
    si = L.t()@s2L
    si+= e*N**2 #Sigma=L^TS^2L+lambda I
    return torch.inverse(si)

def response_si(x1,mu,si):
    # response using sigma inverse(slow)
    # r=(x-mu)Sigma^-1(x-mu), where Sigma=L^TS^2L+lambda I
    x=x1-mu
    six = x@si
    return torch.sum(six*x,axis=1)

def compute_si1(x):
    # sigma inverse using the math computation, without actually computing the inverse
    # v Sigma v^T=v(L^TS^2L+lambda I)v^T=diag(S^2,lambda...) so
    # Sigma = v^T diag(S^2,lambda...) v and Sigma^-1 = v^T diag(S^-2,1/lambda...) v and
    # Sigma^-1 = 1/lambda I - L^T (1/lambda-1/(S^2+lambda)) L
    # Sigma^-1 = 1/lambda I - L^T (S^2/lambda(S^2+lambda)) L
    u,s,v = torch.linalg.svd(x)
    la=N**2
    L=v[0:k,:]
    S=s[0:k]
    s2L=(S**2/(S**2+la)/la).unsqueeze(1)*L
    si = -L.t()@s2L
    si+= e*(1/la)
    return si

def classify(x,mx,L,S,la):
    nj=x.shape[0]
    nc=mx.shape[0]
    k=L.shape[1]
    d=L.shape[2]
    out=torch.zeros(nj,nc,device=device)
    for i in range(nc):
        #ld=(d-k)*np.log(la)+torch.sum(torch.log(S[i,:]**2+la))
        r=response(x,mx[i,:].to(device),L[i,:,:].to(device),S[i,:].to(device),la)
#        r=response1(x,mx[i,:].to(device))
        out[:,i] = r#+ld
    py=torch.argmin(out,dim=1)
    return py


la=0.01
i=0
emptyx=1
for j in range(nc):
    x=load_datat(j)
    if emptyx:
        allx=x
        emptyx=0
    else:
        allx=torch.cat((allx,x),dim=0)
    l=j#label[names[j][0:9]]
    if j==0:
        y=torch.zeros(x.shape[0])+l
    else:
        y=torch.cat((y,torch.zeros(x.shape[0])+l))
    if (j%1000==999)|(j==nc-1):
        print(j+1)    
        pyj=classify(allx,mx,L,S,la)
        emptyx=1
        if i==0:
            py=pyj 
            i=1
        else:
            py=torch.cat((py,pyj),dim=0)
print('done')
confmat=confusion_matrix(y.cpu().numpy(),py.cpu().numpy())
print('accuracy=',np.sum(np.diag(confmat))/np.sum(confmat)*100)
#r, c = linear_sum_assignment(-confmat)
#print('accuracy=',np.sum(confmat[r,c])/np.sum(confmat)*100)
#cv2.imwrite('c:/tmp/conf.png',confmat)
# Out:
# 1000
# done
# accuracy= 71.25
